# %%
import numpy as np
import torch
import cv2
import mediapipe as mp
from scipy.spatial import distance

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### mediapipe로 낙상 감지

# %%
# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# 랜드마크 인덱스 정의 (예: 코, 왼쪽 어깨, 오른쪽 어깨 등)
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]  # 총 11개 랜드마크

# Threshold 값 정의
threshold_normal = 5.5   # 일반 상태로 간주되는 속도 임계값
threshold_danger = 8.5   # 위험 상태로 간주되는 속도 임계값

def calculate_head_upper_body_speed(keypoints, prev_keypoints):
    h = np.array([keypoints[0, 0], keypoints[0, 1]])   # 머리 좌표
    l = np.array([keypoints[11, 0], keypoints[11, 1]])  # 왼쪽 어깨 좌표
    r = np.array([keypoints[12, 0], keypoints[12, 1]])  # 오른쪽 어깨 좌표

    # 이전 프레임의 좌표가 없는 경우 속도는 0으로 설정
    if prev_keypoints is None:
        return 0.0

    prev_h = np.array([prev_keypoints[0, 0], prev_keypoints[0, 1]])
    prev_l = np.array([prev_keypoints[11, 0], prev_keypoints[11, 1]])
    prev_r = np.array([prev_keypoints[12, 0], prev_keypoints[12, 1]])

    # 현재 프레임과 이전 프레임의 상체 중심 계산
    center_new = (h + l + r) / 3
    center_prev = (prev_h + prev_l + prev_r) / 3

    # 유클리드 거리 계산 (속도)
    speed = distance.euclidean(center_new, center_prev)
    return speed

# 클래스 이름 정의
class_names = {0: 'Normal', 1: 'Fall', 2: 'Danger'}

def calculate_and_draw_bbox(frame, landmarks):
    x_coordinates = landmarks[:, 0]
    y_coordinates = landmarks[:, 1]
    
    x1 = max(0, int(np.min(x_coordinates)))
    y1 = max(0, int(np.min(y_coordinates)))
    x2 = min(frame.shape[1], int(np.max(x_coordinates)))
    y2 = min(frame.shape[0], int(np.max(y_coordinates)))
    
    bbox_width = x2 - x1
    bbox_height = y2 - y1
    
    # 바운딩 박스를 조금 더 넓게 조정 (각 방향으로 패딩 추가)
    padding = 50
    x1 = max(0, x1 - padding)
    y1 = max(0, y1 - padding)
    x2 = min(frame.shape[1], x2 + padding)
    y2 = min(frame.shape[0], y2 + padding)

    return (x1, y1, x2, y2), bbox_width, bbox_height

# 낙상 감지 함수
def detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter):
    global determine_fall
    
    if determine_fall:
        return 1, fall_frame_counter
    
    speed = calculate_head_upper_body_speed(landmarks, prev_landmarks)
    _, bbox_width, bbox_height = calculate_and_draw_bbox(frame, landmarks)
    bbox_ratio = bbox_width / bbox_height if bbox_height != 0 else float('inf')
    
    if speed < threshold_normal and bbox_ratio < 0.7:
        bbox_class = 0  # Normal
    elif speed < threshold_normal and bbox_ratio >= 0.7 : 
        bbox_class = 0
    elif speed >= threshold_danger or bbox_ratio > 1:
        bbox_class = 1  # Fall
    else:
        bbox_class = 2  # Danger
            
    print(f"Speed: {speed}, bbox_ratio: {bbox_ratio}")
    print(f"Predicted class: {bbox_class}")
    
    # Fall_counter 업데이트
    if bbox_class == 1:
        fall_frame_counter += 1
        if fall_frame_counter >= 10:
            determine_fall = True
    else:
        fall_frame_counter = 0

    return bbox_class, fall_frame_counter

video_path = "D:\\human_fall\\re_video\\training\\Y\\01571_Y_A_SY_C1.mp4" 
cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_path = 'C:\\Users\\user\\Desktop\\prj_sample_vid\\mediapipe_sample_10.mp4'
out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

# 프레임 처리 루프 
fall_frame_counter = 0
determine_fall = False
prev_landmarks = None

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results_pose = pose.process(rgb_frame)

    if results_pose.pose_landmarks:
        landmarks = np.array([[lm.x * width, lm.y * height, lm.z] for lm in results_pose.pose_landmarks.landmark])
       
        label, fall_frame_counter = detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter)  
        print(f"Predicted Class: {label}")  

        # 바운딩 박스와 라벨 그리기 
        bbox, _, _ = calculate_and_draw_bbox(frame, landmarks)
        color = (0, 255, 0) if label == 0 else ((0, 255, 255) if label == 2 else (0, 0, 255)) 
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color, 2)
        class_name = class_names[label]
        cv2.putText(frame, f'Class: {class_name}', (bbox[0], bbox[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

        if determine_fall: 
            height, width = frame.shape[ :2]
            rec_height = 100
            rec_y = (height - rec_height) // 2
            cv2.rectangle(frame, (0, rec_y), (width, rec_y + rec_height), (0, 0, 255), -1)
            font = cv2.FONT_HERSHEY_DUPLEX
            text_size = cv2.getTextSize('FALL', font, 2, 3)[0]
            text_x = (width - text_size[0]) // 2
            text_y = rec_y + (rec_height + text_size[1]) // 2
            cv2.putText(frame, 'FALL', (text_x, text_y), font, 2, (255, 255, 255), 3)
            
            # 랜드마크 표시 
        mp_drawing.draw_landmarks(frame, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        prev_landmarks = landmarks

    # 프레임 저장 및 출력 
    out.write(frame) 
    cv2.imshow('Fall Detection', frame) 
    if cv2.waitKey(1) & 0xFF == ord('q'):
         break
cv2
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Speed: 0.0, bbox_ratio: 0.7847619047619048
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.636473906369345, bbox_ratio: 0.8278688524590164
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3984608198567345, bbox_ratio: 0.825531914893617
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1223776186832883, bbox_ratio: 0.8246753246753247
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.33264837165053, bbox_ratio: 0.8209606986899564
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.942893205852423, bbox_ratio: 0.8246753246753247
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.475954517408404, bbox_ratio: 0.8293216630196937
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.429694795019066, bbox_ratio: 0.8434579439252337
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.563060153754624, bbox_ratio: 0.8160377358490566
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.478553467141773, bbox_ratio: 0.8911111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.008700481807585, bbox_ratio: 0.8671171171171171
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9677587318200707, bbox_ratio: 0.7990314769975787
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3932085463589186, bbox_ratio: 0.8131067961165048
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.185907909201984, bbox_ratio: 0.9059633027522935
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.335222704811058, bbox_ratio: 0.8901869158878505
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.928198556320361, bbox_ratio: 0.8575
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.8709655261207905, bbox_ratio: 0.903755868544601
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.2545452091102725, bbox_ratio: 0.9277899343544858
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3578468725190476, bbox_ratio: 0.9087048832271762
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.417793983232232, bbox_ratio: 0.8955555555555555
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0143476544610723, bbox_ratio: 0.9481327800829875
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.42337232025352, bbox_ratio: 0.9254658385093167
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7695929162063258, bbox_ratio: 0.9224137931034483
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.826649345773907, bbox_ratio: 0.9054054054054054
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.327903482575749, bbox_ratio: 0.9503916449086162
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.028309689483784, bbox_ratio: 0.9606299212598425
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.481338868138953, bbox_ratio: 0.9734748010610079
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.692007501973164, bbox_ratio: 0.9919354838709677
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.364285983653914, bbox_ratio: 1.010840108401084
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.5843390774683535, bbox_ratio: 1.0245231607629428
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.265757564252664, bbox_ratio: 1.043956043956044
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.25186232043059, bbox_ratio: 1.0550964187327823
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6688053677412547, bbox_ratio: 1.058011049723757
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.355309825929955, bbox_ratio: 1.058011049723757
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.664430913805616, bbox_ratio: 1.0637119113573408
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.480293889630688, bbox_ratio: 1.0722222222222222
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.558709165397329, bbox_ratio: 1.0807799442896935
# Predicted class: 1
# Predicted Class: 1
# Speed: 2.5902261867094607, bbox_ratio: 1.0868347338935573
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8364031512352494, bbox_ratio: 1.1014084507042254
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.7506530332799155, bbox_ratio: 1.112994350282486
# Predicted class: 1
# Predicted Class: 1
# Speed: 4.148059442211984, bbox_ratio: 1.1101694915254237
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.911490275029635, bbox_ratio: 1.1246458923512748
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.038364421167344, bbox_ratio: 1.1221590909090908
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.6651647187898, bbox_ratio: 1.1306818181818181
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.78576367807163, bbox_ratio: 1.13314447592068
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.543985026230426, bbox_ratio: 1.13314447592068
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3595407781241318, bbox_ratio: 1.13314447592068
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.377682843961741, bbox_ratio: 1.1242937853107344
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.874746099276877, bbox_ratio: 1.1299435028248588
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2225149784803477, bbox_ratio: 1.13314447592068
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.077427002650037, bbox_ratio: 1.1457142857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6479269331838355, bbox_ratio: 1.1457142857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.98146207133717, bbox_ratio: 1.1485714285714286
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.0780184116102225, bbox_ratio: 1.1457142857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7891131942879746, bbox_ratio: 1.1396011396011396
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9589350706744884, bbox_ratio: 1.1359773371104815
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.417046977340265, bbox_ratio: 1.1271186440677967
# Predicted class: 1
# Predicted Class: 1
# Speed: 4.6054636944860174, bbox_ratio: 1.1271186440677967
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.270023037450113, bbox_ratio: 1.1242937853107344
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.796655170861854, bbox_ratio: 1.1235955056179776
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.908975252503898, bbox_ratio: 1.1204481792717087
# Predicted class: 1
# Predicted Class: 1
# Speed: 3.7583952778753154, bbox_ratio: 1.1292134831460674
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3825045754346914, bbox_ratio: 1.1098591549295775
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.4647942796344995, bbox_ratio: 1.098314606741573
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.37773626719796, bbox_ratio: 1.0921787709497206
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.490627227078861, bbox_ratio: 1.0796703296703296
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.839370417283887, bbox_ratio: 1.0591397849462365
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.674428378095716, bbox_ratio: 1.0398936170212767
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.270095481145946, bbox_ratio: 1.0263157894736843
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.092901280813989, bbox_ratio: 1.0
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.069073662518753, bbox_ratio: 0.9148936170212766
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.343189999930164, bbox_ratio: 0.9129411764705883
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.403049305119388, bbox_ratio: 0.9218009478672986
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.815185781447264, bbox_ratio: 0.9629629629629629
# Predicted class: 1
# Predicted Class: 1
# Speed: 6.6329518812110475, bbox_ratio: 0.9420289855072463
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.118158850676305, bbox_ratio: 0.9312796208530806
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.142042465438557, bbox_ratio: 0.9093023255813953
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.065834251649227, bbox_ratio: 0.903448275862069
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.221788557177323, bbox_ratio: 0.89749430523918
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.786704725925317, bbox_ratio: 0.8914027149321267
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.757591762117836, bbox_ratio: 0.8772321428571429
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.838619637641638, bbox_ratio: 0.8650442477876106
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.107482583946883, bbox_ratio: 0.8537117903930131
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.933435234954685, bbox_ratio: 0.8333333333333334
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.854384018535142, bbox_ratio: 0.7934560327198364
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.865555321337985, bbox_ratio: 0.746615087040619
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.7754062917078866, bbox_ratio: 0.74373795761079
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.197579426259591, bbox_ratio: 0.7309160305343512
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.824087968537374, bbox_ratio: 0.7047970479704797
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.459104624281232, bbox_ratio: 0.7044609665427509
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.321133314088603, bbox_ratio: 0.6910420475319927
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.841211810274017, bbox_ratio: 0.6714542190305206
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.8307458140501245, bbox_ratio: 0.6578014184397163
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.628253914035458, bbox_ratio: 0.658273381294964
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.143380948485437, bbox_ratio: 0.6423487544483986
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.69018331057076, bbox_ratio: 0.615916955017301
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.69819373118702, bbox_ratio: 0.596964586846543
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.6005531882396085, bbox_ratio: 0.5856905158069884
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.175203962882058, bbox_ratio: 0.5662847790507365
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.381075885193861, bbox_ratio: 0.5501618122977346
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.842951402127946, bbox_ratio: 0.5389507154213037
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.082222461935954, bbox_ratio: 0.5492957746478874
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.612356589661322, bbox_ratio: 0.5615384615384615
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.846290631110044, bbox_ratio: 0.5618320610687023
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.478058942484785, bbox_ratio: 0.52
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.302767422833535, bbox_ratio: 0.5171919770773639
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.071859842696897, bbox_ratio: 0.5137085137085137
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.760574455852161, bbox_ratio: 0.4915492957746479
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.679800330406586, bbox_ratio: 0.46994535519125685
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.292669155196542, bbox_ratio: 0.46630727762803237
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.738747785639074, bbox_ratio: 0.4845222072678331
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.070398033111957, bbox_ratio: 0.4845222072678331
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.352138829898203, bbox_ratio: 0.5094339622641509
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.060883965944764, bbox_ratio: 0.5256756756756756
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.181255754970861, bbox_ratio: 0.543859649122807
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9258127868635424, bbox_ratio: 0.5620736698499318
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0063175858565803, bbox_ratio: 0.5542168674698795
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.805831495435862, bbox_ratio: 0.5540720961281709
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5115532949954065, bbox_ratio: 0.5389784946236559
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1248544525811283, bbox_ratio: 0.5254691689008043
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09089832083062879, bbox_ratio: 0.5093085106382979
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.40724554938072594, bbox_ratio: 0.49273447820343463
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6262984100560356, bbox_ratio: 0.4775132275132275
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8797757112234468, bbox_ratio: 0.46825396825396826
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6420125656012722, bbox_ratio: 0.4574468085106383
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3858633849931433, bbox_ratio: 0.45139813581890814
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.046575248551079, bbox_ratio: 0.44666666666666666
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.7511296309413216, bbox_ratio: 0.4434087882822903
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1889458116120926, bbox_ratio: 0.440745672436751
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3223707961656348, bbox_ratio: 0.42895086321381143
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2976119786561977, bbox_ratio: 0.41832669322709165
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3731911710882498, bbox_ratio: 0.4116865869853918
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.164738480954053, bbox_ratio: 0.40185676392572944
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.588882697497235, bbox_ratio: 0.3968253968253968
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.921196099626998, bbox_ratio: 0.38998682476943347
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.527675444182644, bbox_ratio: 0.3805774278215223
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.470155119944192, bbox_ratio: 0.3745072273324573
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.311079591354669, bbox_ratio: 0.3756544502617801
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.6661756387486735, bbox_ratio: 0.37922077922077924
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.09910819559501, bbox_ratio: 0.3832258064516129
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.068861857142969, bbox_ratio: 0.38303341902313626
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.776310617080364, bbox_ratio: 0.38917525773195877
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.0862597069806, bbox_ratio: 0.38996138996138996
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.029312154887886, bbox_ratio: 0.39405684754521964
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.435799119872974, bbox_ratio: 0.3984476067270375
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.504918171872323, bbox_ratio: 0.4059662775616083
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.734272360132881, bbox_ratio: 0.41374837872892345
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.134746805801474, bbox_ratio: 0.42077922077922075
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.8982552344644015, bbox_ratio: 0.42597402597402595
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.048488880963157, bbox_ratio: 0.43302990897269183
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.477976415378882, bbox_ratio: 0.4406779661016949
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.032744143063292, bbox_ratio: 0.4445893089960887
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.352234657346593, bbox_ratio: 0.4444444444444444
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7903209456617546, bbox_ratio: 0.44836601307189544
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.389088998720656, bbox_ratio: 0.45098039215686275
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.001599491069722, bbox_ratio: 0.45609436435124506
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.993254190279588, bbox_ratio: 0.45718050065876153
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.639293140583257, bbox_ratio: 0.45910290237467016
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.4216963081686345, bbox_ratio: 0.4683377308707124
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.426746493238727, bbox_ratio: 0.475
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.6226546275512135, bbox_ratio: 0.48353096179183136
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.942307177956663, bbox_ratio: 0.4894459102902375
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.119694677935092, bbox_ratio: 0.4920844327176781
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.751892913186174, bbox_ratio: 0.5059288537549407
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.282735759042825, bbox_ratio: 0.5210526315789473
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.40811706525193, bbox_ratio: 0.52832674571805
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.102370655385015, bbox_ratio: 0.5428194993412385
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2430785093968733, bbox_ratio: 0.5514511873350924
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7344871142152667, bbox_ratio: 0.5621693121693122
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.495667101373065, bbox_ratio: 0.5668874172185431
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.511713939671611, bbox_ratio: 0.5750332005312085
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.482915243330997, bbox_ratio: 0.5765645805592543
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.539993313601057, bbox_ratio: 0.5872170439414115
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.606483159968737, bbox_ratio: 0.5952063914780293
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.5033381665617607, bbox_ratio: 0.5992010652463382
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.327855308663132, bbox_ratio: 0.5986666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.965641502818248, bbox_ratio: 0.6042780748663101
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.593530376252399, bbox_ratio: 0.6058981233243967
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.2034807863655885, bbox_ratio: 0.6005361930294906
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.395478649817149, bbox_ratio: 0.5959731543624162
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.544901234936302, bbox_ratio: 0.6061827956989247
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.518535423844476, bbox_ratio: 0.6054054054054054
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.107736542793911, bbox_ratio: 0.5899864682002707
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.0566537208004485, bbox_ratio: 0.592391304347826
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.656941008044497, bbox_ratio: 0.5753968253968254
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.32113342341123, bbox_ratio: 0.5688311688311688
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.388798368467651, bbox_ratio: 0.5561290322580645
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.214212004156638, bbox_ratio: 0.5514138817480719
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.248239084245245, bbox_ratio: 0.5537084398976982
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.598495306665549, bbox_ratio: 0.5578406169665809
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.401652693710052, bbox_ratio: 0.5561224489795918
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.260066188916459, bbox_ratio: 0.5579617834394904
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.956215313982755, bbox_ratio: 0.5641025641025641
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.568004857011388, bbox_ratio: 0.574025974025974
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.826099188517526, bbox_ratio: 0.5795006570302234
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.444038948784041, bbox_ratio: 0.5862977602108037
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.752376309347224, bbox_ratio: 0.5904887714663144
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.720247597241674, bbox_ratio: 0.5938748335552596
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.860896016470455, bbox_ratio: 0.5929919137466307
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.07544927202526, bbox_ratio: 0.5917241379310345
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.191954382255105, bbox_ratio: 0.5974930362116991
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6644304456145567, bbox_ratio: 0.5876577840112202
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.218366362133598, bbox_ratio: 0.5816901408450704
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1602471091586684, bbox_ratio: 0.5689900426742532
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.459824849016474, bbox_ratio: 0.5616045845272206
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3011121995930606, bbox_ratio: 0.5331412103746398
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0924853441554547, bbox_ratio: 0.5183016105417276
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9537865347733536, bbox_ratio: 0.502906976744186
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.840696416888227, bbox_ratio: 0.49640287769784175
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.905817324571302, bbox_ratio: 0.49573863636363635
# Predicted class: 1
# Predicted Class: 1
# Speed: 9.465919866842254, bbox_ratio: 0.48739495798319327
# Predicted class: 1
# Predicted Class: 1
# Speed: 3.4993011286766422, bbox_ratio: 0.47960618846694797
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4474510207860953, bbox_ratio: 0.47164591977869985
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.595233515073435, bbox_ratio: 0.45454545454545453
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.4208535767049546, bbox_ratio: 0.444743935309973
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0872613967504243, bbox_ratio: 0.4272108843537415
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.150838679949494, bbox_ratio: 0.4250681198910082
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.80466398487977, bbox_ratio: 0.41346153846153844
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8749499448938574, bbox_ratio: 0.4118457300275482
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2988047985762647, bbox_ratio: 0.4118457300275482
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7345788933530986, bbox_ratio: 0.4090909090909091
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6015938593755366, bbox_ratio: 0.40852819807427787
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.249176503865473, bbox_ratio: 0.4060356652949246
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8700611470493802, bbox_ratio: 0.40273972602739727
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.768631483090013, bbox_ratio: 0.4010989010989011
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7295755030564935, bbox_ratio: 0.40384615384615385
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.532019093211289, bbox_ratio: 0.40355677154582764
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2226745190546984, bbox_ratio: 0.40272108843537413
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9312738623796332, bbox_ratio: 0.4056987788331072
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4089071891001612, bbox_ratio: 0.4059539918809202
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.293312280719923, bbox_ratio: 0.408355795148248
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0492385914555953, bbox_ratio: 0.40860215053763443
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12545831952727135, bbox_ratio: 0.41420911528150134
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.851225043172141, bbox_ratio: 0.4234354194407457
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6009261704108506, bbox_ratio: 0.4321808510638298
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.814319653907457, bbox_ratio: 0.440745672436751
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5272116116314092, bbox_ratio: 0.44121532364597094
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2272138921930478, bbox_ratio: 0.43989431968295906
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3448035149185422, bbox_ratio: 0.44342105263157894
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.7376655745812568, bbox_ratio: 0.442257217847769
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.989589461296816, bbox_ratio: 0.4358974358974359
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.710169089541193, bbox_ratio: 0.42431761786600497
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5973893867851305, bbox_ratio: 0.41829268292682925
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.47121192213998486, bbox_ratio: 0.4211822660098522
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2888088124096173, bbox_ratio: 0.4257178526841448
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.48402526499412796, bbox_ratio: 0.42803504380475593
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.42660725620262124, bbox_ratio: 0.4298245614035088
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5889444927915088, bbox_ratio: 0.44372574385511
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3916885705642732, bbox_ratio: 0.44836601307189544
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3594705008717492, bbox_ratio: 0.45013123359580054
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7024976817685389, bbox_ratio: 0.4507227332457293
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6017493092468418, bbox_ratio: 0.4577836411609499
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6218859601849529, bbox_ratio: 0.47035573122529645
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8109477777479666, bbox_ratio: 0.4723684210526316
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7979650552300661, bbox_ratio: 0.4763157894736842
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9631033225402617, bbox_ratio: 0.48157894736842105
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8388618442233409, bbox_ratio: 0.4836173001310616
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.4555637047134065, bbox_ratio: 0.4888888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9730915061769965, bbox_ratio: 0.4934725848563969
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8215560260422428, bbox_ratio: 0.4954367666232073
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.660641501513706, bbox_ratio: 0.4961038961038961
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5381585942644223, bbox_ratio: 0.4974025974025974
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.281259842804551, bbox_ratio: 0.49740932642487046
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.040073508277843, bbox_ratio: 0.4948051948051948
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.231945168142882, bbox_ratio: 0.4889753566796368
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.255242912058998, bbox_ratio: 0.4780361757105943
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5710329631920192, bbox_ratio: 0.472258064516129
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8088907105484096, bbox_ratio: 0.4689922480620155
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.912469189420488, bbox_ratio: 0.4645161290322581
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.575991035031979, bbox_ratio: 0.4568854568854569
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.4087980538257754, bbox_ratio: 0.45186136071887034
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.40717968446133, bbox_ratio: 0.4434447300771208
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6474716382965298, bbox_ratio: 0.43943298969072164
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7479275954388878, bbox_ratio: 0.44041450777202074
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.280903075609842, bbox_ratio: 0.4365284974093264
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.932780752825876, bbox_ratio: 0.43281653746770027
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.523267251687941, bbox_ratio: 0.43134715025906734
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0542597069575996, bbox_ratio: 0.43005181347150256
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.335916410034594, bbox_ratio: 0.4326424870466321
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8322855874247483, bbox_ratio: 0.4333764553686934
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2588051420798023, bbox_ratio: 0.432258064516129
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9353666426999365, bbox_ratio: 0.43281653746770027
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7706172827448703, bbox_ratio: 0.43170103092783507
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.4130857694933217, bbox_ratio: 0.4335483870967742
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.082637150267124, bbox_ratio: 0.4385510996119017
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0862789435120976, bbox_ratio: 0.43911917098445596
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7818438571967855, bbox_ratio: 0.4430051813471503
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5085837023249873, bbox_ratio: 0.44689119170984454
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1416236613865, bbox_ratio: 0.4483204134366925
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9938679427663317, bbox_ratio: 0.44903225806451613
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8235763377762126, bbox_ratio: 0.4503225806451613
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6395738949457455, bbox_ratio: 0.45045045045045046
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7595920644912026, bbox_ratio: 0.4555984555984556
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5512818459786882, bbox_ratio: 0.4594594594594595
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8406070400049652, bbox_ratio: 0.4645161290322581
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8776816145379619, bbox_ratio: 0.4670967741935484
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.23031346843330167, bbox_ratio: 0.4721141374837873
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3329753172038823, bbox_ratio: 0.4727272727272727
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8137954679332167, bbox_ratio: 0.4745762711864407
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7212672087635953, bbox_ratio: 0.47575360419397117
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.28642248523650166, bbox_ratio: 0.47757255936675463
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0721919014965047, bbox_ratio: 0.47877984084880637
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9463915770227712, bbox_ratio: 0.48
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3738695366266641, bbox_ratio: 0.48322147651006714
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7148914838297489, bbox_ratio: 0.4817813765182186
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2181628415879049, bbox_ratio: 0.47696476964769646
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7419858898217057, bbox_ratio: 0.4822888283378747
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.79464686303274, bbox_ratio: 0.48633879781420764
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6089950126024553, bbox_ratio: 0.4883720930232558
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.044500480064644, bbox_ratio: 0.4945054945054945
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.707031477689773, bbox_ratio: 0.5013774104683195
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8406717270300175, bbox_ratio: 0.5062068965517241
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3938794588353485, bbox_ratio: 0.5139275766016713
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.7534540425902976, bbox_ratio: 0.5167130919220055
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2826537317309867, bbox_ratio: 0.5253521126760563
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.820066932002626, bbox_ratio: 0.5289957567185289
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6306968064101786, bbox_ratio: 0.5319148936170213
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9989983972414038, bbox_ratio: 0.5376955903271693
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.355883312870806, bbox_ratio: 0.54
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8818097720161044, bbox_ratio: 0.5429799426934098
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.024314477934848, bbox_ratio: 0.5446685878962536
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.688340930342478, bbox_ratio: 0.5500725689404935
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.584735443148325, bbox_ratio: 0.554093567251462
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.723946574408149, bbox_ratio: 0.5601173020527859
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.07716498143146, bbox_ratio: 0.5663716814159292
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.065650343685779, bbox_ratio: 0.5729166666666666
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.781404897472591, bbox_ratio: 0.5761194029850746
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.357592621807182, bbox_ratio: 0.5787106446776612
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.797633492550881, bbox_ratio: 0.5830815709969789
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.450689698053738, bbox_ratio: 0.5884146341463414
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.34108349203336, bbox_ratio: 0.5877862595419847
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.334172475337093, bbox_ratio: 0.5916795069337443
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.733908203529089, bbox_ratio: 0.5906976744186047
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.3746434624944746, bbox_ratio: 0.6034755134281201
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.927239777011607, bbox_ratio: 0.6141479099678456
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.886098982414023, bbox_ratio: 0.6284779050736498
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.742298487996768, bbox_ratio: 0.6404682274247492
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.771683926942867, bbox_ratio: 0.649746192893401
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.323649613537919, bbox_ratio: 0.6666666666666666
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.733069868931645, bbox_ratio: 0.6807017543859649
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.941276563730105, bbox_ratio: 0.675
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.081024275835729, bbox_ratio: 0.5851063829787234
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.863753201019741, bbox_ratio: 0.6132075471698113
# Predicted class: 2
# Predicted Class: 2
# Speed: 6.3860200790236545, bbox_ratio: 0.6777003484320557
# Predicted class: 2
# Predicted Class: 2
# Speed: 9.326802122448946, bbox_ratio: 0.6560402684563759
# Predicted class: 1
# Predicted Class: 1
# Speed: 7.211483475399052, bbox_ratio: 0.6840277777777778
# Predicted class: 2
# Predicted Class: 2
# Speed: 9.053107981228713, bbox_ratio: 0.7625482625482626
# Predicted class: 1
# Predicted Class: 1
# Speed: 8.035367193996672, bbox_ratio: 0.7827788649706457
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.752257961431683, bbox_ratio: 0.8083832335329342
# Predicted class: 1
# Predicted Class: 1
# Speed: 9.490288835085249, bbox_ratio: 0.8319838056680162
# Predicted class: 1
# Predicted Class: 1
# Speed: 4.4295806172419105, bbox_ratio: 0.8383838383838383
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.68763927195538, bbox_ratio: 0.842741935483871
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.217048101482701, bbox_ratio: 0.8511066398390342
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.892599800049738, bbox_ratio: 0.8686868686868687
# Predicted class: 2
# Predicted Class: 2
# Speed: 7.3776108860967, bbox_ratio: 0.8843813387423936
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.848243744157227, bbox_ratio: 0.9020408163265307
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.715058782737522, bbox_ratio: 0.898989898989899
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.209576620362353, bbox_ratio: 0.8977955911823647
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.933341799289552, bbox_ratio: 0.9050505050505051
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.032036802116772, bbox_ratio: 0.9131313131313131
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.4722187365305945, bbox_ratio: 0.926829268292683
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.82844776705828, bbox_ratio: 0.9366053169734151
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.206743166606154, bbox_ratio: 0.9547325102880658
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.508789153372256, bbox_ratio: 0.979253112033195
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.481231302350515, bbox_ratio: 1.0020876826722338
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.051399069735141, bbox_ratio: 1.0252631578947369
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.962299407502954, bbox_ratio: 1.0402542372881356
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.59026898832093, bbox_ratio: 1.0600858369098713
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.214192090303225, bbox_ratio: 1.0831509846827134
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.566703210709409, bbox_ratio: 1.1042128603104213
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.836644496389395, bbox_ratio: 1.1376975169300225
# Predicted class: 1
# Predicted Class: 1
# Speed: 6.130829900308363, bbox_ratio: 1.165137614678899
# Predicted class: 1
# Predicted Class: 1
# Speed: 6.934990754309699, bbox_ratio: 1.2023529411764706
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.3439468462857205, bbox_ratio: 1.2355769230769231
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.238053563860675, bbox_ratio: 1.2955665024630543
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.792437741087548, bbox_ratio: 1.3125
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.265692846622842, bbox_ratio: 1.3350253807106598
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.352484237906605, bbox_ratio: 1.3624678663239074
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.845836056297323, bbox_ratio: 1.390625
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.736770724617539, bbox_ratio: 1.4126984126984128
# Predicted class: 1
# Predicted Class: 1
# Speed: 6.664584058843167, bbox_ratio: 1.4316353887399464
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.5798733753102026, bbox_ratio: 1.4565217391304348
# Predicted class: 1
# Predicted Class: 1
# Speed: 5.9504437242202455, bbox_ratio: 1.4917582417582418
# Predicted class: 1
# Predicted Class: 1
# Speed: 6.870097340295973, bbox_ratio: 1.5308988764044944
# Predicted class: 1
# Predicted Class: 1
# Speed: 7.983278432114238, bbox_ratio: 1.5689655172413792
# Predicted class: 1
# Predicted Class: 1
# Speed: 8.381219579810292, bbox_ratio: 1.5797101449275361
# Predicted class: 1
# Predicted Class: 1
# Speed: 8.822466301226138, bbox_ratio: 1.6287425149700598
# Predicted class: 1
# Predicted Class: 1
# Speed: 9.039753849381183, bbox_ratio: 1.691358024691358
# Predicted class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1
# Predicted Class: 1

# %% [markdown]
# ## 웹캠으로 mediapipe만을 사용하여 낙상 감지
# * MacOS + iphone

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)

# %%
# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# 랜드마크 인덱스 정의
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]  # 총 11개 랜드마크

# Threshold 값 정의
threshold_normal = 10.5   
threshold_danger = 15.5   

def calculate_head_upper_body_speed(keypoints, prev_keypoints):
    h = np.array([keypoints[0, 0], keypoints[0, 1]])   
    l = np.array([keypoints[11, 0], keypoints[11, 1]])  
    r = np.array([keypoints[12, 0], keypoints[12, 1]])  

    # 이전 프레임의 좌표가 없는 경우 속도는 0으로 설정
    if prev_keypoints is None:
        return 0.0

    prev_h = np.array([prev_keypoints[0, 0], prev_keypoints[0, 1]])
    prev_l = np.array([prev_keypoints[11, 0], prev_keypoints[11, 1]])
    prev_r = np.array([prev_keypoints[12, 0], prev_keypoints[12, 1]])

    # 현재 프레임과 이전 프레임의 상체 중심 계산
    center_new = (h + l + r) / 3
    center_prev = (prev_h + prev_l + prev_r) / 3

    # 유클리드 거리 계산 (속도)
    speed = distance.euclidean(center_new, center_prev)
    return speed

# 클래스 이름 정의
class_names = {0: 'Normal', 1: 'Fall', 2: 'Danger'}

def calculate_and_draw_bbox(frame, landmarks):
    x_coordinates = landmarks[:, 0]
    y_coordinates = landmarks[:, 1]
    
    x1 = max(0, int(np.min(x_coordinates)))
    y1 = max(0, int(np.min(y_coordinates)))
    x2 = min(frame.shape[1], int(np.max(x_coordinates)))
    y2 = min(frame.shape[0], int(np.max(y_coordinates)))
    
    bbox_width = x2 - x1
    bbox_height = y2 - y1
    
    # 바운딩 박스를 조금 더 넓게 조정 (각 방향으로 패딩 추가)
    padding = 50
    x1 = max(0, x1 - padding)
    y1 = max(0, y1 - padding)
    x2 = min(frame.shape[1], x2 + padding)
    y2 = min(frame.shape[0], y2 + padding)

    return (x1, y1, x2, y2), bbox_width, bbox_height

# 낙상 감지 함수
def detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter):
    global determine_fall
    
    if determine_fall:
        return 1, fall_frame_counter
    
    speed = calculate_head_upper_body_speed(landmarks, prev_landmarks)
    _, bbox_width, bbox_height = calculate_and_draw_bbox(frame, landmarks)
    bbox_ratio = bbox_width / bbox_height if bbox_height != 0 else float('inf')
    
    if speed < threshold_normal and bbox_ratio < 0.7:
        bbox_class = 0  # Normal
    elif speed >= threshold_danger or bbox_ratio > 1:
        bbox_class = 1  # Fall
    else:
        bbox_class = 2  # Danger
            
    print(f"Speed: {speed}, bbox_ratio: {bbox_ratio}")
    print(f"Predicted class: {bbox_class}")
    
    # Fall_counter 업데이트
    if bbox_class == 1:
        fall_frame_counter += 1
        if fall_frame_counter >= 10:
            determine_fall = True
    else:
        fall_frame_counter = 0

    return bbox_class, fall_frame_counter

# 웹캠 초기화
cap = cv2.VideoCapture(0)  

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = 30  

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_path = 'webcam_fall_detection.mp4'
out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

# 프레임 처리 루프 
fall_frame_counter = 0
determine_fall = False
prev_landmarks = None

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results_pose = pose.process(rgb_frame)

    if results_pose.pose_landmarks:
        landmarks = np.array([[lm.x * width, lm.y * height, lm.z] for lm in results_pose.pose_landmarks.landmark])
       
        label, fall_frame_counter = detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter)  
        print(f"Predicted Class: {label}")  

        # 바운딩 박스와 라벨 그리기 
        bbox, _, _ = calculate_and_draw_bbox(frame, landmarks)
        color = (0, 255, 0) if label == 0 else ((0, 255, 255) if label == 2 else (0, 0, 255)) 
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color, 2)
        class_name = class_names[label]
        cv2.putText(frame, f'Class: {class_name}', (bbox[0], bbox[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

        if determine_fall: 
            cv2.putText(frame, 'FALL', (10, 30), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 255), 3)
        # 랜드마크 표시 
        mp_drawing.draw_landmarks(frame, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        prev_landmarks = landmarks

    # 프레임 저장 및 출력 
    out.write(frame) 
    cv2.imshow('Fall Detection', frame) 
    if cv2.waitKey(1) & 0xFF == ord('q'):
         break

cap.release()
out.release()
cv2.destroyAllWindows()
cv2.waitKey()
cv2.waitKey(1)

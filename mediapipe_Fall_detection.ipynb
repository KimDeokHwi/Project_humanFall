# %%
import numpy as np
import torch
import cv2
import mediapipe as mp
from scipy.spatial import distance
# Out:
# objc[1441]: Class CaptureDelegate is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x16afe66b8) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x16ce18860). One of the two will be used. Which one is undefined.
# objc[1441]: Class CVWindow is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x16afe6708) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x168c28a68). One of the two will be used. Which one is undefined.
# objc[1441]: Class CVView is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x16afe6730) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x168c28a90). One of the two will be used. Which one is undefined.
# objc[1441]: Class CVSlider is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x16afe6758) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x168c28ab8). One of the two will be used. Which one is undefined.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### mediapipe로 낙상 감지

# %%
# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# 랜드마크 인덱스 정의 (예: 코, 왼쪽 어깨, 오른쪽 어깨 등)
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]  # 총 11개 랜드마크

# Threshold 값 정의
threshold_normal = 10.5   # 일반 상태로 간주되는 속도 임계값
threshold_danger = 15.5   # 위험 상태로 간주되는 속도 임계값

def calculate_head_upper_body_speed(keypoints, prev_keypoints):
    h = np.array([keypoints[0, 0], keypoints[0, 1]])   # 머리 좌표
    l = np.array([keypoints[11, 0], keypoints[11, 1]])  # 왼쪽 어깨 좌표
    r = np.array([keypoints[12, 0], keypoints[12, 1]])  # 오른쪽 어깨 좌표

    # 이전 프레임의 좌표가 없는 경우 속도는 0으로 설정
    if prev_keypoints is None:
        return 0.0

    prev_h = np.array([prev_keypoints[0, 0], prev_keypoints[0, 1]])
    prev_l = np.array([prev_keypoints[11, 0], prev_keypoints[11, 1]])
    prev_r = np.array([prev_keypoints[12, 0], prev_keypoints[12, 1]])

    # 현재 프레임과 이전 프레임의 상체 중심 계산
    center_new = (h + l + r) / 3
    center_prev = (prev_h + prev_l + prev_r) / 3

    # 유클리드 거리 계산 (속도)
    speed = distance.euclidean(center_new, center_prev)
    return speed

# 클래스 이름 정의
class_names = {0: 'Normal', 1: 'Fall', 2: 'Danger'}

def calculate_and_draw_bbox(frame, landmarks):
    x_coordinates = landmarks[:, 0]
    y_coordinates = landmarks[:, 1]
    
    x1 = max(0, int(np.min(x_coordinates)))
    y1 = max(0, int(np.min(y_coordinates)))
    x2 = min(frame.shape[1], int(np.max(x_coordinates)))
    y2 = min(frame.shape[0], int(np.max(y_coordinates)))
    
    bbox_width = x2 - x1
    bbox_height = y2 - y1
    
    # 바운딩 박스를 조금 더 넓게 조정 (각 방향으로 패딩 추가)
    padding = 50
    x1 = max(0, x1 - padding)
    y1 = max(0, y1 - padding)
    x2 = min(frame.shape[1], x2 + padding)
    y2 = min(frame.shape[0], y2 + padding)

    return (x1, y1, x2, y2), bbox_width, bbox_height

# 낙상 감지 함수
def detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter):
    global determine_fall
    
    if determine_fall:
        return 1, fall_frame_counter
    
    speed = calculate_head_upper_body_speed(landmarks, prev_landmarks)
    _, bbox_width, bbox_height = calculate_and_draw_bbox(frame, landmarks)
    bbox_ratio = bbox_width / bbox_height if bbox_height != 0 else float('inf')
    
    if speed < threshold_normal and bbox_ratio < 0.7:
        bbox_class = 0  # Normal
    elif speed >= threshold_danger or bbox_ratio > 1:
        bbox_class = 1  # Fall
    else:
        bbox_class = 2  # Danger
            
    print(f"Speed: {speed}, bbox_ratio: {bbox_ratio}")
    print(f"Predicted class: {bbox_class}")
    
    # Fall_counter 업데이트
    if bbox_class == 1:
        fall_frame_counter += 1
        if fall_frame_counter >= 10:
            determine_fall = True
    else:
        fall_frame_counter = 0

    return bbox_class, fall_frame_counter

video_path = "D:\\041.낙상사고 위험동작 영상-센서 쌍 데이터\\3.개방데이터\\1.데이터\\Validation\\01.원천데이터\\VS\\영상\\N\\N\\01228_O_E_N_C7\\01228_O_E_N_C7.mp4"  
cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_path = 'C:\\Users\\user\\Desktop\\prj_sample_vid\\mediapipe_sample_4.mp4'
out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

# 프레임 처리 루프 
fall_frame_counter = 0
determine_fall = False
prev_landmarks = None

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results_pose = pose.process(rgb_frame)

    if results_pose.pose_landmarks:
        landmarks = np.array([[lm.x * width, lm.y * height, lm.z] for lm in results_pose.pose_landmarks.landmark])
       
        label, fall_frame_counter = detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter)  
        print(f"Predicted Class: {label}")  

        # 바운딩 박스와 라벨 그리기 
        bbox, _, _ = calculate_and_draw_bbox(frame, landmarks)
        color = (0, 255, 0) if label == 0 else ((0, 255, 255) if label == 2 else (0, 0, 255)) 
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color, 2)
        class_name = class_names[label]
        cv2.putText(frame, f'Class: {class_name}', (bbox[0], bbox[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

        if determine_fall: 
            cv2.putText(frame, 'FALL', (10, 30), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 255), 3)
        # 랜드마크 표시 
        mp_drawing.draw_landmarks(frame, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        prev_landmarks = landmarks

    # 프레임 저장 및 출력 
    out.write(frame) 
    cv2.imshow('Fall Detection', frame) 
    if cv2.waitKey(1) & 0xFF == ord('q'):
         break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Speed: 0.0, bbox_ratio: 0.4220314735336195
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.015447515145465, bbox_ratio: 0.45982142857142855
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.027793584328462, bbox_ratio: 0.4740853658536585
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.282396916298011, bbox_ratio: 0.4546875
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.1077580584347615, bbox_ratio: 0.43213728549141966
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.62019822793649, bbox_ratio: 0.4041204437400951
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.113938325964901, bbox_ratio: 0.3614649681528662
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.859646713604942, bbox_ratio: 0.34455128205128205
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.1484307461734184, bbox_ratio: 0.31758957654723124
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.871652617446551, bbox_ratio: 0.2719869706840391
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.268915408994188, bbox_ratio: 0.23366013071895425
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.4605604274034545, bbox_ratio: 0.22350993377483444
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1867369473729728, bbox_ratio: 0.22719734660033167
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.317886104410054, bbox_ratio: 0.23051409618573798
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.058585819650467, bbox_ratio: 0.23383084577114427
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.539821754602326, bbox_ratio: 0.23920265780730898
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1806854201399335, bbox_ratio: 0.24581939799331104
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.001904960001809, bbox_ratio: 0.25210084033613445
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7810637700807344, bbox_ratio: 0.2533783783783784
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.0003905699845, bbox_ratio: 0.2559322033898305
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.447133795847372, bbox_ratio: 0.257679180887372
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.088981516225569, bbox_ratio: 0.2611683848797251
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.5706236026856226, bbox_ratio: 0.2672413793103448
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.979113176471071, bbox_ratio: 0.2708333333333333
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.366794738438266, bbox_ratio: 0.27177700348432055
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.292233766666641, bbox_ratio: 0.2757417102966841
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.758800872787747, bbox_ratio: 0.27768014059753954
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1852851561832085, bbox_ratio: 0.2821869488536155
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.470804892277741, bbox_ratio: 0.2831858407079646
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.242827184806583, bbox_ratio: 0.28520499108734404
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.762195948368782, bbox_ratio: 0.2885304659498208
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5670278865529617, bbox_ratio: 0.2882882882882883
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6370835121901477, bbox_ratio: 0.28804347826086957
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3542857434997349, bbox_ratio: 0.2885662431941924
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6511469863095334, bbox_ratio: 0.29326047358834245
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0570491498416468, bbox_ratio: 0.2967032967032967
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8561863959563842, bbox_ratio: 0.3001841620626151
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6478493237203484, bbox_ratio: 0.30091743119266057
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0816858877756106, bbox_ratio: 0.3020257826887661
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9218928745158563, bbox_ratio: 0.3037037037037037
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.968011141288045, bbox_ratio: 0.30988593155893535
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.200543647736445, bbox_ratio: 0.31640625
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.272359077437699, bbox_ratio: 0.3286004056795132
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8495592432970027, bbox_ratio: 0.3292181069958848
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.7395500917842692, bbox_ratio: 0.3250517598343685
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.6178826839126454, bbox_ratio: 0.33122362869198313
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6878666079435476, bbox_ratio: 0.33191489361702126
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.4833119217613615, bbox_ratio: 0.33121019108280253
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.753212709082602, bbox_ratio: 0.3390928725701944
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.733650059964148, bbox_ratio: 0.3466666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.32493065309931, bbox_ratio: 0.35280898876404493
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5476086829102649, bbox_ratio: 0.3542600896860987
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.982938482021347, bbox_ratio: 0.3550561797752809
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.564717036750992, bbox_ratio: 0.3536036036036036
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.024436207156862, bbox_ratio: 0.3786848072562358
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.708770991718088, bbox_ratio: 0.3886363636363636
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4463131699986504, bbox_ratio: 0.3865168539325843
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5176019252318786, bbox_ratio: 0.3835920177383592
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.481914176946706, bbox_ratio: 0.3788546255506608
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8109374716925093, bbox_ratio: 0.3741648106904232
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.849337170880467, bbox_ratio: 0.37723214285714285
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.955873486495963, bbox_ratio: 0.3694690265486726
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4807793648750789, bbox_ratio: 0.36629213483146067
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.42541028309087525, bbox_ratio: 0.36
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9853148275364374, bbox_ratio: 0.36486486486486486
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.992014047321151, bbox_ratio: 0.3611738148984199
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5356064082616688, bbox_ratio: 0.35650224215246634
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.627259301962022, bbox_ratio: 0.34210526315789475
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2652889829324026, bbox_ratio: 0.3333333333333333
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6389338538627043, bbox_ratio: 0.3275488069414317
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.709149250032161, bbox_ratio: 0.3297644539614561
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3390768447707733, bbox_ratio: 0.3078556263269639
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.540027032003272, bbox_ratio: 0.31210191082802546
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6245608914486833, bbox_ratio: 0.3050847457627119
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.49551606218290756, bbox_ratio: 0.3037974683544304
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.24737057662335746, bbox_ratio: 0.3080168776371308
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6133776714351935, bbox_ratio: 0.3094736842105263
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0243987804303005, bbox_ratio: 0.3147751605995717
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4346513866197296, bbox_ratio: 0.315450643776824
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0205086161998729, bbox_ratio: 0.3161290322580645
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12492876159404447, bbox_ratio: 0.3161290322580645
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02959124940526674, bbox_ratio: 0.31063829787234043
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08065067918208396, bbox_ratio: 0.31263383297644537
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02178731553937923, bbox_ratio: 0.3083511777301927
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.30914070313630426, bbox_ratio: 0.30406852248394006
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.887692598722276, bbox_ratio: 0.30406852248394006
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16816453924889374, bbox_ratio: 0.30472103004291845
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41455011474747644, bbox_ratio: 0.31767337807606266
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5687768087279825, bbox_ratio: 0.31767337807606266
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3393186257143923, bbox_ratio: 0.31767337807606266
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7907910633388942, bbox_ratio: 0.3288888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8492731819763623, bbox_ratio: 0.32894736842105265
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.44622752290216544, bbox_ratio: 0.34216335540838855
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.106864532130081, bbox_ratio: 0.33698030634573306
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9477669004342258, bbox_ratio: 0.33916849015317285
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2774205100471845, bbox_ratio: 0.352549889135255
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.161981268049698, bbox_ratio: 0.3542600896860987
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8801030765328883, bbox_ratio: 0.3348115299334812
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7410078101159474, bbox_ratio: 0.32819383259911894
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.345936857070749, bbox_ratio: 0.3401826484018265
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8931473327884187, bbox_ratio: 0.3401360544217687
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6382696104501046, bbox_ratio: 0.3409090909090909
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.403355595005832, bbox_ratio: 0.33856502242152464
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1164128530640482, bbox_ratio: 0.3282608695652174
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.894332537682948, bbox_ratio: 0.33043478260869563
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.30920683301181784, bbox_ratio: 0.3355263157894737
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4083956592397635, bbox_ratio: 0.3422818791946309
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1756342313791666, bbox_ratio: 0.34606741573033706
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8913688431022408, bbox_ratio: 0.34146341463414637
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.682473269357217, bbox_ratio: 0.3241525423728814
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8379018387124497, bbox_ratio: 0.3347547974413646
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.433254984274258, bbox_ratio: 0.3412526997840173
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9372661544819803, bbox_ratio: 0.350109409190372
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.143382196011669, bbox_ratio: 0.36
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.380150863138155, bbox_ratio: 0.3638392857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.699613841524031, bbox_ratio: 0.36607142857142855
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.495885130545882, bbox_ratio: 0.36807095343680707
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.650664752933301, bbox_ratio: 0.3686534216335541
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1231666531196804, bbox_ratio: 0.36980306345733044
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.9931435197105305, bbox_ratio: 0.36796536796536794
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.3412429489744015, bbox_ratio: 0.3669527896995708
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.212340845401261, bbox_ratio: 0.36324786324786323
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.843626704020551, bbox_ratio: 0.36324786324786323
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1140452000256738, bbox_ratio: 0.3595744680851064
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.5355048068405805, bbox_ratio: 0.3580508474576271
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.482915434294031, bbox_ratio: 0.35654008438818563
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.320982654683944, bbox_ratio: 0.35
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.796734242895316, bbox_ratio: 0.34496919917864477
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1497983696789094, bbox_ratio: 0.3394308943089431
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.202808638283736, bbox_ratio: 0.3333333333333333
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4817203194823427, bbox_ratio: 0.3293172690763052
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0084388906812127, bbox_ratio: 0.3273453093812375
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6927211606166295, bbox_ratio: 0.32936507936507936
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.969746766067327, bbox_ratio: 0.32741617357001973
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6675998611667904, bbox_ratio: 0.32612966601178783
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8569188265412926, bbox_ratio: 0.32108317214700194
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6453369766923767, bbox_ratio: 0.31477927063339733
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9289186897551875, bbox_ratio: 0.31368821292775667
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1606611511704283, bbox_ratio: 0.3068181818181818
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.461281192145445, bbox_ratio: 0.30377358490566037
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.745969557041274, bbox_ratio: 0.299625468164794
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.940641567415562, bbox_ratio: 0.2966417910447761
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9116101171735183, bbox_ratio: 0.2975970425138632
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.3511166165605424, bbox_ratio: 0.2959558823529412
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.453782056931811, bbox_ratio: 0.2959558823529412
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.190250517249375, bbox_ratio: 0.2956204379562044
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.7266751436892058, bbox_ratio: 0.29347826086956524
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.121847505748743, bbox_ratio: 0.2924187725631769
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7817981858510348, bbox_ratio: 0.2926391382405745
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5928895562016687, bbox_ratio: 0.2910714285714286
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9276084774783677, bbox_ratio: 0.2902654867256637
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6496972823095644, bbox_ratio: 0.2907801418439716
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.339935927674153, bbox_ratio: 0.29307282415630553
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.002849164104821, bbox_ratio: 0.2894736842105263
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2039606290410636, bbox_ratio: 0.2879581151832461
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.3595365870670717, bbox_ratio: 0.28422876949740034
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.118441603023906, bbox_ratio: 0.2827586206896552
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8480075890571563, bbox_ratio: 0.281786941580756
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9493578602745605, bbox_ratio: 0.28130360205831906
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1718725767760882, bbox_ratio: 0.28034188034188035
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.492877986431813, bbox_ratio: 0.2789115646258503
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8481603465159853, bbox_ratio: 0.2801358234295416
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.867393697476058, bbox_ratio: 0.2910321489001692
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6362695257614805, bbox_ratio: 0.30405405405405406
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3489584990599355, bbox_ratio: 0.3130287648054145
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.961218520704092, bbox_ratio: 0.31703204047217537
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1714297481148597, bbox_ratio: 0.31986531986531985
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9298894589225841, bbox_ratio: 0.32046979865771813
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9416920354421168, bbox_ratio: 0.3177257525083612
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0637322528910553, bbox_ratio: 0.31666666666666665
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.885248039920075, bbox_ratio: 0.3178036605657238
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0923035954362998, bbox_ratio: 0.31727574750830567
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8066667342679821, bbox_ratio: 0.31825795644891125
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7754782184263356, bbox_ratio: 0.3165829145728643
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8362585607186116, bbox_ratio: 0.3149078726968174
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5323611071480947, bbox_ratio: 0.31438127090301005
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2462084614087312, bbox_ratio: 0.3132328308207705
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0289024592887284, bbox_ratio: 0.3098827470686767
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.218996224354331, bbox_ratio: 0.3082077051926298
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.870691597510744, bbox_ratio: 0.30666666666666664
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6475390798174784, bbox_ratio: 0.30449251247920134
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7169936351860838, bbox_ratio: 0.30198019801980197
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6959743962571435, bbox_ratio: 0.29901960784313725
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7919605482613076, bbox_ratio: 0.2991869918699187
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.884601215624271, bbox_ratio: 0.28846153846153844
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3791329681268762, bbox_ratio: 0.27910685805422647
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.46453539186747683, bbox_ratio: 0.28139904610492844
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8598353350901508, bbox_ratio: 0.2786624203821656
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8293724815757123, bbox_ratio: 0.2711323763955343
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6214325539636837, bbox_ratio: 0.25559105431309903
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.38405170939199273, bbox_ratio: 0.2528
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5609657919207808, bbox_ratio: 0.2548076923076923
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.885340464095634, bbox_ratio: 0.255663430420712
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6372339155605269, bbox_ratio: 0.25811688311688313
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4330212807878528, bbox_ratio: 0.2601626016260163
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5147936985961322, bbox_ratio: 0.25980392156862747
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.23776094604846199, bbox_ratio: 0.2581699346405229
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.023668108237261388, bbox_ratio: 0.2581699346405229
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19161183546451607, bbox_ratio: 0.25732899022801303
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41776675002481717, bbox_ratio: 0.2528548123980424
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8108498640595355, bbox_ratio: 0.24673202614379086
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.796531315278233, bbox_ratio: 0.24713584288052373
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.389394848194952, bbox_ratio: 0.23442622950819672
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1260177540374, bbox_ratio: 0.2257001647446458
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.893514204819815, bbox_ratio: 0.21983471074380165
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.42054135166751627, bbox_ratio: 0.2222222222222222
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6153702512728412, bbox_ratio: 0.225
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.959515122020046, bbox_ratio: 0.22833333333333333
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.945210758773596, bbox_ratio: 0.23529411764705882
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.057617027668111, bbox_ratio: 0.2402044293015332
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2578457331600497, bbox_ratio: 0.24149659863945577
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8340389156796157, bbox_ratio: 0.24786324786324787
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.4663833401054736, bbox_ratio: 0.25257731958762886
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.780304868857685, bbox_ratio: 0.2538860103626943
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.084313290263174, bbox_ratio: 0.25609756097560976
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.684573734553763, bbox_ratio: 0.2631578947368421
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9241257858718672, bbox_ratio: 0.26631393298059963
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.71277557336644, bbox_ratio: 0.2682060390763766
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0253048540258223, bbox_ratio: 0.27549194991055453
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5993008887277567, bbox_ratio: 0.27978339350180503
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9337025210361367, bbox_ratio: 0.2875457875457875
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.067407415346921, bbox_ratio: 0.2933579335793358
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.677473565434183, bbox_ratio: 0.29814814814814816
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1091689936166294, bbox_ratio: 0.3041044776119403
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0613846361873693, bbox_ratio: 0.31273408239700373
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.494164422636737, bbox_ratio: 0.3159851301115242
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.713175747610549, bbox_ratio: 0.3180987202925046
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.223876759562237, bbox_ratio: 0.32656826568265684
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.273988365234585, bbox_ratio: 0.326605504587156
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7883130021332945, bbox_ratio: 0.3290676416819013
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1594389119860247, bbox_ratio: 0.3339483394833948
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.468081709914432, bbox_ratio: 0.3376383763837638
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2202109777605132, bbox_ratio: 0.34074074074074073
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6455257298949975, bbox_ratio: 0.3451492537313433
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0835141503599264, bbox_ratio: 0.34888059701492535
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.582055199051521, bbox_ratio: 0.36
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.138324523200116, bbox_ratio: 0.361376673040153
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.087332813125736, bbox_ratio: 0.36259541984732824
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1258809062300927, bbox_ratio: 0.372848948374761
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5530891915857068, bbox_ratio: 0.38049713193116635
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1642968489633163, bbox_ratio: 0.3857965451055662
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9266704698223889, bbox_ratio: 0.3930635838150289
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.465114223131102, bbox_ratio: 0.40038684719535783
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.520169284396563, bbox_ratio: 0.41050583657587547
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.327215613770045, bbox_ratio: 0.42578125
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.403593184967508, bbox_ratio: 0.42913385826771655
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.198583385732792, bbox_ratio: 0.4393638170974155
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.826632413357168, bbox_ratio: 0.44642857142857145
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.124744695485191, bbox_ratio: 0.45634920634920634
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.467977111572279, bbox_ratio: 0.4601593625498008
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9272854175112006, bbox_ratio: 0.469061876247505
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.162983650795743, bbox_ratio: 0.4759036144578313
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.42401657579747, bbox_ratio: 0.4721115537848606
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2441750225345984, bbox_ratio: 0.48893360160965793
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2322622127677945, bbox_ratio: 0.4979757085020243
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.199840395279038, bbox_ratio: 0.5020408163265306
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.543316075274114, bbox_ratio: 0.5072164948453608
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.438583165801749, bbox_ratio: 0.5135135135135135
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.370422616426737, bbox_ratio: 0.5299145299145299
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.948430502307199, bbox_ratio: 0.5292841648590022
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.660217406750784, bbox_ratio: 0.5384615384615384
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.6275813226727704, bbox_ratio: 0.5535714285714286
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.454579136449406, bbox_ratio: 0.5585585585585585
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.654005399358868, bbox_ratio: 0.5779816513761468
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.614537582389273, bbox_ratio: 0.6013986013986014
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.02585763666128, bbox_ratio: 0.6150234741784038
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.976161481693355, bbox_ratio: 0.6232227488151659
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.369371904112515, bbox_ratio: 0.630071599045346
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.124496601270577, bbox_ratio: 0.642512077294686
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.255768665344739, bbox_ratio: 0.6650124069478908
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.433145725116555, bbox_ratio: 0.6683291770573566
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.557662739778195, bbox_ratio: 0.67
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.446222339580774, bbox_ratio: 0.6741854636591479
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9262032089590053, bbox_ratio: 0.6818181818181818
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.174063513493466, bbox_ratio: 0.6897435897435897
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.751917094823359, bbox_ratio: 0.6987012987012987
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.651698610525035, bbox_ratio: 0.7015706806282722
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.0707039957729543, bbox_ratio: 0.7034120734908137
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.264091332716917, bbox_ratio: 0.7071240105540897
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.5021609578278476, bbox_ratio: 0.7165775401069518
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.5441433805788973, bbox_ratio: 0.739010989010989
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.991953834067114, bbox_ratio: 0.7451523545706371
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.3043106277983023, bbox_ratio: 0.7513966480446927
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.7040576443493616, bbox_ratio: 0.7633802816901408
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.1997785934448497, bbox_ratio: 0.7493112947658402
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.845930615756262, bbox_ratio: 0.7562326869806094
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.7721939898715697, bbox_ratio: 0.7596685082872928
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.8549452156918207, bbox_ratio: 0.7582417582417582
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.1153009206008444, bbox_ratio: 0.7561643835616438
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.780171356070592, bbox_ratio: 0.7643835616438356
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.19094417211205, bbox_ratio: 0.7671232876712328
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.6761333079120457, bbox_ratio: 0.7650273224043715
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.74864168278791, bbox_ratio: 0.771978021978022
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.9933697553921466, bbox_ratio: 0.778393351800554
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.790494617687168, bbox_ratio: 0.7833333333333333
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.6246666688940699, bbox_ratio: 0.778393351800554
# Predicted class: 2
# Predicted Class: 2
# Speed: 0.4848464501338168, bbox_ratio: 0.775623268698061
# Predicted class: 2
# Predicted Class: 2
# Speed: 0.7975650660674605, bbox_ratio: 0.775623268698061
# Predicted class: 2
# Predicted Class: 2
# Speed: 0.050088573911124874, bbox_ratio: 0.775623268698061
# Predicted class: 2
# Predicted Class: 2
# Speed: 0.6301479133467004, bbox_ratio: 0.7651933701657458
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.0571692471156593, bbox_ratio: 0.7589041095890411
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.5364986360004529, bbox_ratio: 0.7561643835616438
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.580155361692664, bbox_ratio: 0.7534246575342466
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.4117691608492637, bbox_ratio: 0.7638888888888888
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.792299043441572, bbox_ratio: 0.7694444444444445
# Predicted class: 2
# Predicted Class: 2
# Speed: 1.5640462867347427, bbox_ratio: 0.7707182320441989
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.2966726468627585, bbox_ratio: 0.7664835164835165
# Predicted class: 2
# Predicted Class: 2
# Speed: 2.5510520095844917, bbox_ratio: 0.7608695652173914
# Predicted class: 2
# Predicted Class: 2
# Speed: 3.3059368928369337, bbox_ratio: 0.7453580901856764
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.369271867554904, bbox_ratio: 0.734375
# Predicted class: 2
# Predicted Class: 2
# Speed: 5.748539968544642, bbox_ratio: 0.7157360406091371
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.712633224847292, bbox_ratio: 0.7032418952618454
# Predicted class: 2
# Predicted Class: 2
# Speed: 4.920085118715991, bbox_ratio: 0.687041564792176
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.377993993411758, bbox_ratio: 0.6811594202898551
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.380506591032505, bbox_ratio: 0.6666666666666666
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.909299489202999, bbox_ratio: 0.6558139534883721
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.228086714165312, bbox_ratio: 0.6415525114155252
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.273875953210149, bbox_ratio: 0.6386363636363637
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.770268651861051, bbox_ratio: 0.6343115124153499
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.0558799378488453, bbox_ratio: 0.6258351893095768
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6822096467015486, bbox_ratio: 0.6194690265486725
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5807905529860777, bbox_ratio: 0.6189427312775331
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2451221979323255, bbox_ratio: 0.6148796498905909
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1348318596405833, bbox_ratio: 0.6170678336980306
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4163125828761762, bbox_ratio: 0.616557734204793
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.547109922024961, bbox_ratio: 0.6152173913043478
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.28910903900528356, bbox_ratio: 0.6152173913043478
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5797654055678051, bbox_ratio: 0.6152173913043478
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.894487913336721, bbox_ratio: 0.6125541125541125
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5203117218154234, bbox_ratio: 0.6086021505376344
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5153447129094085, bbox_ratio: 0.6125541125541125
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7174750076830853, bbox_ratio: 0.6112311015118791
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.011093871137838, bbox_ratio: 0.6051502145922747
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2725139043840173, bbox_ratio: 0.6021505376344086
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7311628692941508, bbox_ratio: 0.5952890792291221
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8023086932715904, bbox_ratio: 0.5897435897435898
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.388468396692514, bbox_ratio: 0.582089552238806
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3645198603929433, bbox_ratio: 0.5765957446808511
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.26492783943828246, bbox_ratio: 0.5735607675906184
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.708085642546891, bbox_ratio: 0.5705128205128205
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9665408838943244, bbox_ratio: 0.5653104925053534
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8355859810571692, bbox_ratio: 0.5641025641025641
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05704216722669929, bbox_ratio: 0.561965811965812
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.25408194501689524, bbox_ratio: 0.55863539445629
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.39164586661901213, bbox_ratio: 0.554140127388535
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1696858778919779, bbox_ratio: 0.5508474576271186
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1395522885965379, bbox_ratio: 0.5421940928270043
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.15482229014598473, bbox_ratio: 0.5357142857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3289560828554513, bbox_ratio: 0.5294117647058824
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2969983513456612, bbox_ratio: 0.5262054507337526
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.42591030321769363, bbox_ratio: 0.5252100840336135
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41584146013294626, bbox_ratio: 0.523109243697479
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3548724666194152, bbox_ratio: 0.5210084033613446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8093752323488577, bbox_ratio: 0.5221052631578947
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5657801257775673, bbox_ratio: 0.52
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1904382984720421, bbox_ratio: 0.52
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2871509736277187, bbox_ratio: 0.5168776371308017
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.28292078694863004, bbox_ratio: 0.5168776371308017
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4512951237038173, bbox_ratio: 0.5147679324894515
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7674806849140334, bbox_ratio: 0.5158562367864693
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0347512535191807, bbox_ratio: 0.5148305084745762
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4304447976805454, bbox_ratio: 0.5127659574468085
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5907956819402806, bbox_ratio: 0.5149572649572649
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9417379541490583, bbox_ratio: 0.5160599571734475
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4653673666166433, bbox_ratio: 0.51931330472103
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.36596732011637595, bbox_ratio: 0.5225806451612903
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2898007267296774, bbox_ratio: 0.531317494600432
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.49373083573465565, bbox_ratio: 0.5334773218142549
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2013100846343037, bbox_ratio: 0.5411255411255411
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.074875749183791, bbox_ratio: 0.5422993492407809
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.40463164681298736, bbox_ratio: 0.5434782608695652
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2723058360563606, bbox_ratio: 0.5446623093681917
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03738213827478551, bbox_ratio: 0.5413043478260869
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08310374300689138, bbox_ratio: 0.5413043478260869
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.14112124907296325, bbox_ratio: 0.5413043478260869
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04806680927296624, bbox_ratio: 0.5413043478260869
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.25473080102498386, bbox_ratio: 0.5401301518438177
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5153610419354826, bbox_ratio: 0.5401301518438177
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.123609396441023, bbox_ratio: 0.5401301518438177
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.14478766333755355, bbox_ratio: 0.5369565217391304
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.21760159397682707, bbox_ratio: 0.5369565217391304
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10944796341759747, bbox_ratio: 0.5369565217391304
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04399329934180102, bbox_ratio: 0.5369565217391304
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.029503298752132884, bbox_ratio: 0.5403050108932462
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.30412166755109776, bbox_ratio: 0.5404814004376368
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.43673371911815634, bbox_ratio: 0.5382932166301969
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4627121360416674, bbox_ratio: 0.543859649122807
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.459430270641927, bbox_ratio: 0.545054945054945
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6038127545795776, bbox_ratio: 0.5462555066079295
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3454258124618827, bbox_ratio: 0.5462555066079295
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8996751012394508, bbox_ratio: 0.5496688741721855
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3438339592200737, bbox_ratio: 0.5496688741721855
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.22108187698652915, bbox_ratio: 0.5474613686534217
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5454391852348568, bbox_ratio: 0.5496688741721855
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7589121641269898, bbox_ratio: 0.5518763796909493
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5756194319199989, bbox_ratio: 0.5496688741721855
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1698815856341302, bbox_ratio: 0.5530973451327433
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4534953585228165, bbox_ratio: 0.5577777777777778
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0792464432309885, bbox_ratio: 0.5590200445434298
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1042931472854796, bbox_ratio: 0.5615212527964206
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3552593545529127, bbox_ratio: 0.5672645739910314
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3246864857990701, bbox_ratio: 0.5627802690582959
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.49340219234723764, bbox_ratio: 0.5615212527964206
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7970808581548148, bbox_ratio: 0.5659955257270693
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5603059574317066, bbox_ratio: 0.5739910313901345
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.32402068720373073, bbox_ratio: 0.5762331838565022
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5051896010102702, bbox_ratio: 0.57847533632287
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4402594974909226, bbox_ratio: 0.5807174887892377
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5329789170323438, bbox_ratio: 0.5807174887892377
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.43647530447173327, bbox_ratio: 0.5829596412556054
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09655550394988952, bbox_ratio: 0.5829596412556054
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16816861316652207, bbox_ratio: 0.5816554809843401
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.31032843609022714, bbox_ratio: 0.5803571428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5640551191971207, bbox_ratio: 0.576837416481069
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.15583481455494164, bbox_ratio: 0.5723830734966593
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1418107064987711, bbox_ratio: 0.5701559020044543
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12218461050072255, bbox_ratio: 0.5688888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.13845274903576307, bbox_ratio: 0.5666666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.17106779708147368, bbox_ratio: 0.565410199556541
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16593079819061238, bbox_ratio: 0.565410199556541
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10185978225266319, bbox_ratio: 0.565410199556541
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1937460702634145, bbox_ratio: 0.5641592920353983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09374458560471284, bbox_ratio: 0.5641592920353983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02612949328633624, bbox_ratio: 0.5641592920353983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.006255291167877253, bbox_ratio: 0.5641592920353983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0387580235110297, bbox_ratio: 0.5641592920353983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4226422405299945, bbox_ratio: 0.565410199556541
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05059742093898986, bbox_ratio: 0.565410199556541
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.24744507466696933, bbox_ratio: 0.5666666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.22339243703285216, bbox_ratio: 0.5666666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16349206047025658, bbox_ratio: 0.5679287305122495
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.23340682140359692, bbox_ratio: 0.5679287305122495
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.14734077707003812, bbox_ratio: 0.5679287305122495
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.18096236527282963, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0595574191879843, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19342639067469572, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.403945138195155, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1340863736050198, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.177499162756612, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.15588025382985676, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1068322978934005, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07421185497615908, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07109176449719126, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05064899762539264, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07781141264301006, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03979576338175569, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.025840696082616525, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.009499304718187725, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06815389064418957, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08490971995946348, bbox_ratio: 0.5682326621923938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.46763679162933136, bbox_ratio: 0.5659955257270693
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3729552752503308, bbox_ratio: 0.5659955257270693
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.24442470551933512, bbox_ratio: 0.5659955257270693
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.287248274596545, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2889502986644094, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.181339932211034, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10562110925378002, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10699189657812495, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.029628793582690455, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.056873140260273326, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0907318759193258, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1559852848081972, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05200369257911206, bbox_ratio: 0.5634743875278396
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03641368855288747, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06080619682327403, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07761809920911612, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04339041758714816, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10732479335177932, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2519083672946755, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.13596697450340914, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16340480155913223, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.22039712597860742, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1552446067112695, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16403961718334686, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07689325739704922, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08582519526917075, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.132143836414589, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12469960772796079, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12050338277007905, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2540873692378554, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5100728770756181, bbox_ratio: 0.5647321428571429
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.34397920792022735, bbox_ratio: 0.5669642857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.25942116994118175, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.18496510809799613, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16555851615389516, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1050061191132685, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.13535449891626467, bbox_ratio: 0.5644444444444444
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08855734922704485, bbox_ratio: 0.5644444444444444
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3124659897777021, bbox_ratio: 0.5657015590200446
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.21439832015762678, bbox_ratio: 0.5679287305122495
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.13349236383055574, bbox_ratio: 0.5666666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2318977474130527, bbox_ratio: 0.5666666666666667
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1111325344595991, bbox_ratio: 0.5688888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09815799491568586, bbox_ratio: 0.5676274944567627
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06647756865233596, bbox_ratio: 0.5676274944567627
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09431077417266244, bbox_ratio: 0.5676274944567627
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.37896779516968804, bbox_ratio: 0.5688888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.25082897441855206, bbox_ratio: 0.5688888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.14146138760002133, bbox_ratio: 0.5688888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3204316318255181, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2980001117518212, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.18835679249554801, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19458601980453372, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1120861770618605, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.014942786252932062, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.014799071212440772, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.016594591483943853, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.007839046253950741, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08599739111701322, bbox_ratio: 0.5711111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06793338857152915, bbox_ratio: 0.5733333333333334
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19594362110201147, bbox_ratio: 0.579064587973274
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10903910699490976, bbox_ratio: 0.5812917594654788
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03943005212299759, bbox_ratio: 0.5812917594654788
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.008871775419113732, bbox_ratio: 0.5812917594654788
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.003625195067723391, bbox_ratio: 0.5848214285714286
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04107509075501389, bbox_ratio: 0.5870535714285714
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0839858311481245, bbox_ratio: 0.5870535714285714
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10610311046779097, bbox_ratio: 0.5857461024498887
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.010466461572047435, bbox_ratio: 0.5857461024498887
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05742434595754918, bbox_ratio: 0.5822222222222222
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.18780194010448387, bbox_ratio: 0.5822222222222222
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0985883574125277, bbox_ratio: 0.58
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.034637451171875, bbox_ratio: 0.58
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06690890445906125, bbox_ratio: 0.58
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.008569457599735358, bbox_ratio: 0.58
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05741973826043999, bbox_ratio: 0.58
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07942437792813421, bbox_ratio: 0.5812917594654788
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04844675383219869, bbox_ratio: 0.5835189309576837
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04612777086405097, bbox_ratio: 0.5879732739420935
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07352908451922402, bbox_ratio: 0.5879732739420935
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05855766022513509, bbox_ratio: 0.5902004454342984
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03274685459040687, bbox_ratio: 0.5888888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1296020659190436, bbox_ratio: 0.5888888888888889
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.15979186874443405, bbox_ratio: 0.5902004454342984
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07751213998588938, bbox_ratio: 0.5902004454342984
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.112901567709863, bbox_ratio: 0.5902004454342984
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07043659604070965, bbox_ratio: 0.5879732739420935
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.040961061277628594, bbox_ratio: 0.5879732739420935
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.11128371617219539, bbox_ratio: 0.5892857142857143
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.056748023784016416, bbox_ratio: 0.5915178571428571
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3942590873049779, bbox_ratio: 0.5919282511210763
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2289854101436561, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.045895922027872384, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.029477618416667257, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04329604513687271, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.012414865439383624, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.021714108709083038, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.011338128825709549, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.042193289656298115, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.011595166924902556, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.012808027145457769, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04220488919683668, bbox_ratio: 0.5910112359550562
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.100727375766336, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10938740191917483, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10005819957998023, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02539808968894244, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02030341039280297, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03371364862274957, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.01908773426520965, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.029181841925304024, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06673615140757802, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07966957010570606, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09216952035007882, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05686051186044391, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.052829463615965334, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.031609587008275146, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.09223057939675158, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.02957866669269401, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08019089790056104, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.008756059865604751, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.11419807457365488, bbox_ratio: 0.5900900900900901
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.10991027980764659, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16060528273295535, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05033225457681266, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06849165514049273, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05655408748619731, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03769525583694083, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08928074026096317, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06776574440358704, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.064409093460666, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.14357784710475377, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.05470485384805053, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08555160621770154, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03759884909805926, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.026262979074344245, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.004608536777033639, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.045552573177463765, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.060434507913346626, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1296681640114069, bbox_ratio: 0.5904977375565611
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.03282569855250779, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04878311974899196, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.012755907351421665, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.011693129287161817, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.008182593714379705, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0628179663726779, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.06084647687142579, bbox_ratio: 0.5891647855530474
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.07592729218414963, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0304492080266102, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.04333648985361758, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.0554965612951003, bbox_ratio: 0.5878378378378378
# Predicted class: 0
# Predicted Class: 0

# %% [markdown]
# ## 웹캠으로 mediapipe만을 사용하여 낙상 감지
# * MacOS + iphone

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# 랜드마크 인덱스 정의
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]  # 총 11개 랜드마크

# Threshold 값 정의
threshold_normal = 20.5   
threshold_danger = 40.5   

def calculate_head_upper_body_speed(keypoints, prev_keypoints):
    h = np.array([keypoints[0, 0], keypoints[0, 1]])   
    l = np.array([keypoints[11, 0], keypoints[11, 1]])  
    r = np.array([keypoints[12, 0], keypoints[12, 1]])  

    # 이전 프레임의 좌표가 없는 경우 속도는 0으로 설정
    if prev_keypoints is None:
        return 0.0

    prev_h = np.array([prev_keypoints[0, 0], prev_keypoints[0, 1]])
    prev_l = np.array([prev_keypoints[11, 0], prev_keypoints[11, 1]])
    prev_r = np.array([prev_keypoints[12, 0], prev_keypoints[12, 1]])

    # 현재 프레임과 이전 프레임의 상체 중심 계산
    center_new = (h + l + r) / 3
    center_prev = (prev_h + prev_l + prev_r) / 3

    # 유클리드 거리 계산 (속도)
    speed = distance.euclidean(center_new, center_prev)
    return speed

# 클래스 이름 정의
class_names = {0: 'Normal', 1: 'Fall', 2: 'Danger'}

def calculate_and_draw_bbox(frame, landmarks):
    x_coordinates = landmarks[:, 0]
    y_coordinates = landmarks[:, 1]
    
    x1 = max(0, int(np.min(x_coordinates)))
    y1 = max(0, int(np.min(y_coordinates)))
    x2 = min(frame.shape[1], int(np.max(x_coordinates)))
    y2 = min(frame.shape[0], int(np.max(y_coordinates)))
    
    bbox_width = x2 - x1
    bbox_height = y2 - y1
    
    # 바운딩 박스를 조금 더 넓게 조정 (각 방향으로 패딩 추가)
    padding = 50
    x1 = max(0, x1 - padding)
    y1 = max(0, y1 - padding)
    x2 = min(frame.shape[1], x2 + padding)
    y2 = min(frame.shape[0], y2 + padding)

    return (x1, y1, x2, y2), bbox_width, bbox_height

# 낙상 감지 함수
def detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter):
    global determine_fall
    
    if determine_fall:
        return 1, fall_frame_counter
    
    speed = calculate_head_upper_body_speed(landmarks, prev_landmarks)
    _, bbox_width, bbox_height = calculate_and_draw_bbox(frame, landmarks)
    bbox_ratio = bbox_width / bbox_height if bbox_height != 0 else float('inf')
    
    if speed < threshold_normal and bbox_ratio < 0.7:
        bbox_class = 0  # Normal
    elif speed < threshold_normal and bbox_ratio > 0.7 : 
        bbox_class = 0    
    elif speed >= threshold_danger or bbox_ratio > 1:
        bbox_class = 1  # Fall
    else:
        bbox_class = 2  # Danger
            
    print(f"Speed: {speed}, bbox_ratio: {bbox_ratio}")
    print(f"Predicted class: {bbox_class}")
    
    # Fall_counter 업데이트
    if bbox_class == 1:
        fall_frame_counter += 1
        if fall_frame_counter >= 20:
            determine_fall = True
    else:
        fall_frame_counter = 0

    return bbox_class, fall_frame_counter

# 웹캠 초기화
cap = cv2.VideoCapture(0)  

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = 60 

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_path = 'webcam_fall_detection_5.mp4'
out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

# 프레임 처리 루프 
fall_frame_counter = 0
determine_fall = False
prev_landmarks = None

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results_pose = pose.process(rgb_frame)

    if results_pose.pose_landmarks:
        landmarks = np.array([[lm.x * width, lm.y * height, lm.z] for lm in results_pose.pose_landmarks.landmark])
       
        label, fall_frame_counter = detect_fall(frame, landmarks, prev_landmarks, fall_frame_counter)  
        print(f"Predicted Class: {label}")  

        # 바운딩 박스와 라벨 그리기 
        bbox, _, _ = calculate_and_draw_bbox(frame, landmarks)
        color = (0, 255, 0) if label == 0 else ((0, 255, 255) if label == 2 else (0, 0, 255)) 
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color, 2)
        class_name = class_names[label]
        cv2.putText(frame, f'Class: {class_name}', (bbox[0], bbox[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

        if determine_fall: 
            # 프레임의 크기 가져오기
            height, width = frame.shape[:2]
    
            # 사각형의 크기와 위치 계산
            rect_height = 60
            rect_y = (height - rect_height) // 2
    
            # 빨간색 사각형 그리기
            cv2.rectangle(frame, (0, rect_y), (width, rect_y + rect_height), (0, 0, 255), -1)
    
            # "FALL" 텍스트 표시
            text = "FALL"
            text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_DUPLEX, 1, 2)[0]
            text_x = (width - text_size[0]) // 2
            text_y = rect_y + (rect_height + text_size[1]) // 2
            cv2.putText(frame, text, (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX, 1, (255, 255, 255), 2)
            #cv2.putText(frame, 'FALL', (10, 30), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 255), 3)
        # 랜드마크 표시 
        mp_drawing.draw_landmarks(frame, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        prev_landmarks = landmarks

    # 프레임 저장 및 출력 
    out.write(frame) 
    cv2.imshow('Fall Detection', frame) 
    if cv2.waitKey(1) & 0xFF == ord('q'):
         break

cap.release()
out.release()

cv2.waitKey()
cv2.destroyAllWindows()

cv2.waitKey(1)
# Out:
# Speed: 0.0, bbox_ratio: 0.39192139737991266
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.329955388018117, bbox_ratio: 0.3971553610503282
# Predicted class: 2
# Predicted Class: 2
# Speed: 10.227396310641906, bbox_ratio: 0.4287292817679558
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.35128221519001, bbox_ratio: 0.41629464285714285
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.89451044104991, bbox_ratio: 0.4392735527809308
# Predicted class: 0
# Predicted Class: 0
# Speed: 43.99328067768847, bbox_ratio: 0.4582366589327146
# Predicted class: 1
# Predicted Class: 1
# Speed: 47.09797981247319, bbox_ratio: 0.4837587006960557
# Predicted class: 1
# Predicted Class: 1
# Speed: 41.375797531913435, bbox_ratio: 0.5046728971962616
# Predicted class: 1
# Predicted Class: 1
# Speed: 28.991854659267307, bbox_ratio: 0.5512367491166078
# Predicted class: 2
# Predicted Class: 2
# Speed: 26.300119689943532, bbox_ratio: 0.5592417061611374
# Predicted class: 2
# Predicted Class: 2
# Speed: 27.254094658562547, bbox_ratio: 0.5751789976133651
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.03239822711608, bbox_ratio: 0.5769230769230769
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.913116976769169, bbox_ratio: 0.585247883917775
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.348126870029497, bbox_ratio: 0.5728155339805825
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.904992940143947, bbox_ratio: 0.5740514075887393
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.647417000872988, bbox_ratio: 0.5740740740740741
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.196936766365752, bbox_ratio: 0.4806973848069738
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.576449298150605, bbox_ratio: 0.49937106918238994
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.77330503670453, bbox_ratio: 0.4873417721518987
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.171700468367462, bbox_ratio: 0.476010101010101
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.604126349656205, bbox_ratio: 0.4269521410579345
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.23351628595929, bbox_ratio: 0.43219264892268694
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.306692236921236, bbox_ratio: 0.40707964601769914
# Predicted class: 0
# Predicted Class: 0
# Speed: 19.873696931824924, bbox_ratio: 0.3793969849246231
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.205782818263312, bbox_ratio: 0.42947103274559195
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.743715252949764, bbox_ratio: 0.3944374209860936
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.54043808386488, bbox_ratio: 0.34600760456273766
# Predicted class: 0
# Predicted Class: 0
# Speed: 19.02694772012485, bbox_ratio: 0.35658914728682173
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.176679738092295, bbox_ratio: 0.3841145833333333
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.61680823751165, bbox_ratio: 0.34810951760104303
# Predicted class: 0
# Predicted Class: 0
# Speed: 19.962958969428858, bbox_ratio: 0.3215686274509804
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.541321071925907, bbox_ratio: 0.28534031413612565
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.814987610319136, bbox_ratio: 0.29473684210526313
# Predicted class: 2
# Predicted Class: 2
# Speed: 13.759173450365479, bbox_ratio: 0.2648221343873518
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.066430221887362, bbox_ratio: 0.24078947368421053
# Predicted class: 0
# Predicted Class: 0
# Speed: 38.080192280958784, bbox_ratio: 0.23451910408432147
# Predicted class: 2
# Predicted Class: 2
# Speed: 8.274062046188599, bbox_ratio: 0.24834874504623514
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.892150784311657, bbox_ratio: 0.25129533678756477
# Predicted class: 0
# Predicted Class: 0
# Speed: 86.68400438116261, bbox_ratio: 0.3196405648267009
# Predicted class: 1
# Predicted Class: 1
# Speed: 23.086330158407883, bbox_ratio: 0.3645699614890886
# Predicted class: 2
# Predicted Class: 2
# Speed: 33.30360455198299, bbox_ratio: 0.40664961636828645
# Predicted class: 2
# Predicted Class: 2
# Speed: 32.82685620908877, bbox_ratio: 0.41959798994974873
# Predicted class: 2
# Predicted Class: 2
# Speed: 32.77561728474874, bbox_ratio: 0.4477987421383648
# Predicted class: 2
# Predicted Class: 2
# Speed: 39.33619867540966, bbox_ratio: 0.473551637279597
# Predicted class: 2
# Predicted Class: 2
# Speed: 45.074132980984224, bbox_ratio: 0.4528301886792453
# Predicted class: 1
# Predicted Class: 1
# Speed: 50.26485619600372, bbox_ratio: 0.3853779429987608
# Predicted class: 1
# Predicted Class: 1
# Speed: 58.67220620060076, bbox_ratio: 0.34355828220858897
# Predicted class: 1
# Predicted Class: 1
# Speed: 72.91692655599131, bbox_ratio: 0.4175824175824176
# Predicted class: 1
# Predicted Class: 1
# Speed: 84.64855270072384, bbox_ratio: 0.48108747044917255
# Predicted class: 1
# Predicted Class: 1
# Speed: 100.56431963696213, bbox_ratio: 0.5374707259953162
# Predicted class: 1
# Predicted Class: 1
# Speed: 110.60854740907189, bbox_ratio: 0.606280193236715
# Predicted class: 1
# Predicted Class: 1
# Speed: 161.97497280021344, bbox_ratio: 0.7776162790697675
# Predicted class: 1
# Predicted Class: 1
# Speed: 153.0225524491124, bbox_ratio: 1.0216962524654833
# Predicted class: 1
# Predicted Class: 1
# Speed: 119.45054498969849, bbox_ratio: 1.2042105263157894
# Predicted class: 1
# Predicted Class: 1
# Speed: 583.7150858671281, bbox_ratio: 2.814977973568282
# Predicted class: 1
# Predicted Class: 1
# Speed: 81.97043564500353, bbox_ratio: 2.764925373134328
# Predicted class: 1
# Predicted Class: 1
# Speed: 88.28482645723963, bbox_ratio: 2.6572438162544167
# Predicted class: 1
# Predicted Class: 1
# Speed: 427.4200940236222, bbox_ratio: 0.42597087378640774
# Predicted class: 1
# Predicted Class: 1
# Speed: 10.724647161280098, bbox_ratio: 0.4126611957796014
# Predicted class: 0
# Predicted Class: 0
# Speed: 30.79542465780512, bbox_ratio: 0.39285714285714285
# Predicted class: 2
# Predicted Class: 2
# Speed: 15.263711586065586, bbox_ratio: 0.39101123595505616
# Predicted class: 0
# Predicted Class: 0
# Speed: 528.825015851752, bbox_ratio: 0.28774193548387095
# Predicted class: 1
# Predicted Class: 1
# Speed: 152.03616004683462, bbox_ratio: 0.31859756097560976
# Predicted class: 1
# Predicted Class: 1
# Speed: 176.7426502350762, bbox_ratio: 1.2285714285714286
# Predicted class: 1
# Predicted Class: 1
# Speed: 34.59865963100057, bbox_ratio: 1.2195845697329377
# Predicted class: 1
# Predicted Class: 1
# Speed: 19.488996242613425, bbox_ratio: 1.2347560975609757
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.26014897041982, bbox_ratio: 1.2257217847769029
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.785803588042905, bbox_ratio: 1.3041237113402062
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.801413009341683, bbox_ratio: 1.3307692307692307
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.4071909710235, bbox_ratio: 1.3237179487179487
# Predicted class: 0
# Predicted Class: 0
# Speed: 30.59266853549858, bbox_ratio: 1.3149350649350648
# Predicted class: 1
# Predicted Class: 1
# Speed: 12.42728117783257, bbox_ratio: 1.1818181818181819
# Predicted class: 0
# Predicted Class: 0
# Speed: 280.4080379202669, bbox_ratio: 1.4232365145228216
# Predicted class: 1
# Predicted Class: 1
# Speed: 286.34155558289, bbox_ratio: 0.9413793103448276
# Predicted class: 1
# Predicted Class: 1
# Speed: 205.67163243475855, bbox_ratio: 0.976456009913259
# Predicted class: 1
# Predicted Class: 1
# Speed: 140.0080899303109, bbox_ratio: 1.5555555555555556
# Predicted class: 1
# Predicted Class: 1
# Speed: 198.81084062955188, bbox_ratio: 1.0343074968233799
# Predicted class: 1
# Predicted Class: 1
# Speed: 71.0030193934056, bbox_ratio: 1.1031636863823935
# Predicted class: 1
# Predicted Class: 1
# Speed: 42.48856796796734, bbox_ratio: 1.084985835694051
# Predicted class: 1
# Predicted Class: 1
# Speed: 94.11938400416577, bbox_ratio: 0.9913669064748202
# Predicted class: 1
# Predicted Class: 1
# Speed: 97.85088968515957, bbox_ratio: 0.8707015130674003
# Predicted class: 1
# Predicted Class: 1
# Speed: 35.81646563475752, bbox_ratio: 0.8326585695006747
# Predicted class: 2
# Predicted Class: 2
# Speed: 104.79555476396978, bbox_ratio: 0.7672413793103449
# Predicted class: 1
# Predicted Class: 1
# Speed: 47.890923337789694, bbox_ratio: 0.7613941018766756
# Predicted class: 1
# Predicted Class: 1
# Speed: 11.666525706435756, bbox_ratio: 0.7173366834170855
# Predicted class: 0
# Predicted Class: 0
# Speed: 48.20295005737424, bbox_ratio: 0.6962025316455697
# Predicted class: 1
# Predicted Class: 1
# Speed: 47.8881763625713, bbox_ratio: 1.0608695652173914
# Predicted class: 1
# Predicted Class: 1
# Speed: 470.4669682060319, bbox_ratio: 0.5611111111111111
# Predicted class: 1
# Predicted Class: 1
# Speed: 25.88819548130845, bbox_ratio: 0.5425925925925926
# Predicted class: 2
# Predicted Class: 2
# Speed: 36.886719887175566, bbox_ratio: 0.5712962962962963
# Predicted class: 2
# Predicted Class: 2
# Speed: 41.64511537692314, bbox_ratio: 0.524074074074074
# Predicted class: 1
# Predicted Class: 1
# Speed: 39.642737793536874, bbox_ratio: 0.4935185185185185
# Predicted class: 2
# Predicted Class: 2
# Speed: 22.176918018402542, bbox_ratio: 0.5009259259259259
# Predicted class: 2
# Predicted Class: 2
# Speed: 25.739317225019875, bbox_ratio: 0.5111111111111111
# Predicted class: 2
# Predicted Class: 2
# Speed: 27.204135902221097, bbox_ratio: 0.4935185185185185
# Predicted class: 2
# Predicted Class: 2
# Speed: 25.45483003077637, bbox_ratio: 0.4935185185185185
# Predicted class: 2
# Predicted Class: 2
# Speed: 34.680377527944906, bbox_ratio: 0.48333333333333334
# Predicted class: 2
# Predicted Class: 2
# Speed: 24.287298062289643, bbox_ratio: 0.47129629629629627
# Predicted class: 2
# Predicted Class: 2
# Speed: 24.416400860658786, bbox_ratio: 0.5027777777777778
# Predicted class: 2
# Predicted Class: 2
# Speed: 29.523417526133482, bbox_ratio: 0.55
# Predicted class: 2
# Predicted Class: 2
# Speed: 22.84501036035838, bbox_ratio: 0.6888888888888889
# Predicted class: 2
# Predicted Class: 2
# Speed: 19.31690749427803, bbox_ratio: 0.7268518518518519
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.499104710951294, bbox_ratio: 0.7342592592592593
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.602542754687077, bbox_ratio: 0.6666666666666666
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.057106473970332, bbox_ratio: 0.6657407407407407
# Predicted class: 0
# Predicted Class: 0
# Speed: 31.52842734784043, bbox_ratio: 0.6962962962962963
# Predicted class: 2
# Predicted Class: 2
# Speed: 29.448498952861296, bbox_ratio: 0.7564814814814815
# Predicted class: 2
# Predicted Class: 2
# Speed: 35.59478832585562, bbox_ratio: 0.8324074074074074
# Predicted class: 2
# Predicted Class: 2
# Speed: 26.91658943759956, bbox_ratio: 0.975
# Predicted class: 2
# Predicted Class: 2
# Speed: 30.61682335500843, bbox_ratio: 0.8481481481481481
# Predicted class: 2
# Predicted Class: 2
# Speed: 13.777994239349438, bbox_ratio: 0.775
# Predicted class: 0
# Predicted Class: 0
# Speed: 22.647604300647302, bbox_ratio: 0.7685185185185185
# Predicted class: 2
# Predicted Class: 2
# Speed: 20.759265383149312, bbox_ratio: 0.7731481481481481
# Predicted class: 2
# Predicted Class: 2
# Speed: 14.58550600795593, bbox_ratio: 0.7657407407407407
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.411572026227756, bbox_ratio: 0.8064814814814815
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.711366538597074, bbox_ratio: 1.0277777777777777
# Predicted class: 0
# Predicted Class: 0
# Speed: 22.31252729125561, bbox_ratio: 1.1055555555555556
# Predicted class: 1
# Predicted Class: 1
# Speed: 9.738934881780832, bbox_ratio: 0.9490740740740741
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.01342305905057, bbox_ratio: 0.8787037037037037
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.847698258737601, bbox_ratio: 0.8907407407407407
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.306400279178533, bbox_ratio: 1.0037037037037038
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.50818668833221, bbox_ratio: 1.0314814814814814
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.07629654792755, bbox_ratio: 1.0175925925925926
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.614418948314935, bbox_ratio: 1.0527777777777778
# Predicted class: 1
# Predicted Class: 1
# Speed: 22.59494125969465, bbox_ratio: 1.037962962962963
# Predicted class: 1
# Predicted Class: 1
# Speed: 15.500652448393515, bbox_ratio: 1.0351851851851852
# Predicted class: 0
# Predicted Class: 0
# Speed: 23.741420372574755, bbox_ratio: 1.0777777777777777
# Predicted class: 1
# Predicted Class: 1
# Speed: 29.459695403183627, bbox_ratio: 1.0027777777777778
# Predicted class: 1
# Predicted Class: 1
# Speed: 38.69524367640488, bbox_ratio: 1.1425925925925926
# Predicted class: 1
# Predicted Class: 1
# Speed: 34.53869038386563, bbox_ratio: 1.162037037037037
# Predicted class: 1
# Predicted Class: 1
# Speed: 47.153441588608544, bbox_ratio: 1.0872794800371401
# Predicted class: 1
# Predicted Class: 1
# Speed: 54.35499413650435, bbox_ratio: 1.0344497607655503
# Predicted class: 1
# Predicted Class: 1
# Speed: 56.357700470529366, bbox_ratio: 0.9695481335952849
# Predicted class: 1
# Predicted Class: 1
# Speed: 37.832492279210676, bbox_ratio: 0.8963110667996012
# Predicted class: 2
# Predicted Class: 2
# Speed: 23.63739448000166, bbox_ratio: 0.7416413373860182
# Predicted class: 2
# Predicted Class: 2
# Speed: 14.316792404039974, bbox_ratio: 0.8026449643947101
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.888374918791236, bbox_ratio: 0.9383350462487153
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.512129718211039, bbox_ratio: 0.811340206185567
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.774066328315183, bbox_ratio: 0.8980021030494216
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.192349770731056, bbox_ratio: 0.9373007438894793
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.377885516932505, bbox_ratio: 0.9440860215053763
# Predicted class: 2
# Predicted Class: 2
# Speed: 29.50325208738471, bbox_ratio: 0.9717698154180239
# Predicted class: 2
# Predicted Class: 2
# Speed: 35.37650037554614, bbox_ratio: 0.9956236323851203
# Predicted class: 2
# Predicted Class: 2
# Speed: 23.31256787837417, bbox_ratio: 1.0154525386313467
# Predicted class: 1
# Predicted Class: 1
# Speed: 19.924578642467857, bbox_ratio: 1.041111111111111
# Predicted class: 0
# Predicted Class: 0
# Speed: 23.400603869315386, bbox_ratio: 1.082313681868743
# Predicted class: 1
# Predicted Class: 1
# Speed: 17.893924356284842, bbox_ratio: 1.0858416945373468
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.920945949983096, bbox_ratio: 1.1328125
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.05742240590263, bbox_ratio: 1.0840807174887892
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.899617743792897, bbox_ratio: 1.0259887005649717
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0940265900191672, bbox_ratio: 0.9173272933182333
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2547445285032113, bbox_ratio: 0.8529411764705882
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.16825939123707, bbox_ratio: 0.777027027027027
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.75578695244666, bbox_ratio: 0.7905935050391937
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.811195354051645, bbox_ratio: 0.8015695067264574
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.300054701210131, bbox_ratio: 0.7949599083619702
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.064596445251201, bbox_ratio: 0.7308132875143184
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.631459098857565, bbox_ratio: 0.765661252900232
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.710212230838875, bbox_ratio: 0.7082352941176471
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.239107842396955, bbox_ratio: 0.794425087108014
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.4978381438201023, bbox_ratio: 0.8032979976442874
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.45636683776974, bbox_ratio: 0.8011834319526627
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.10401112358774, bbox_ratio: 0.7612293144208038
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.259701986556523, bbox_ratio: 0.7713270142180095
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5839781544802176, bbox_ratio: 0.7914183551847438
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.1393712971754884, bbox_ratio: 0.8712753277711561
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.436882398852043, bbox_ratio: 0.9809976247030879
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.403751133737618, bbox_ratio: 0.9751479289940829
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.53251467290671, bbox_ratio: 0.9443786982248521
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.126292403512442, bbox_ratio: 1.0378698224852072
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.970395001669664, bbox_ratio: 1.0673758865248226
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.5824637701877275, bbox_ratio: 1.0802833530106257
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9251962819892847, bbox_ratio: 1.083627797408716
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.030922850294611, bbox_ratio: 1.0528169014084507
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.808075110054014, bbox_ratio: 1.0610328638497653
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.901728996375903, bbox_ratio: 1.130281690140845
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.993492164561369, bbox_ratio: 1.1384976525821595
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.423016030628991, bbox_ratio: 1.119718309859155
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.697644704035035, bbox_ratio: 1.1041420118343195
# Predicted class: 1
# Predicted Class: 1
# Speed: 24.160692795795367, bbox_ratio: 1.0071428571428571
# Predicted class: 1
# Predicted Class: 1
# Speed: 37.832141202665284, bbox_ratio: 0.7359617682198327
# Predicted class: 2
# Predicted Class: 2
# Speed: 42.89390289190838, bbox_ratio: 0.6302521008403361
# Predicted class: 1
# Predicted Class: 1
# Speed: 31.336384768418927, bbox_ratio: 0.5980746089049338
# Predicted class: 2
# Predicted Class: 2
# Speed: 26.63866335443452, bbox_ratio: 0.5908543922984356
# Predicted class: 2
# Predicted Class: 2
# Speed: 22.64541910292338, bbox_ratio: 0.6009615384615384
# Predicted class: 2
# Predicted Class: 2
# Speed: 23.414196377199254, bbox_ratio: 0.5467625899280576
# Predicted class: 2
# Predicted Class: 2
# Speed: 13.673903339867811, bbox_ratio: 0.5131578947368421
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.039180302217277, bbox_ratio: 0.5107655502392344
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.004921851040846, bbox_ratio: 0.4922526817640048
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.860067401879573, bbox_ratio: 0.499404052443385
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.894896810268536, bbox_ratio: 0.4630071599045346
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.492446789899488, bbox_ratio: 0.44922341696535245
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.10087649184101, bbox_ratio: 0.4479041916167665
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.515392165043467, bbox_ratio: 0.4473684210526316
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6511832445672936, bbox_ratio: 0.44138755980861244
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5229325855201779, bbox_ratio: 0.4461722488038278
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6484559122824216, bbox_ratio: 0.4700956937799043
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9102591989815151, bbox_ratio: 0.48383233532934133
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8087942672705033, bbox_ratio: 0.4796650717703349
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1688398410902434, bbox_ratio: 0.47613365155131265
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41896201126290755, bbox_ratio: 0.4731823599523242
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0051063932036068, bbox_ratio: 0.4719904648390942
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2437932070730882, bbox_ratio: 0.4684147794994041
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5389369213400206, bbox_ratio: 0.464839094159714
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.39752183696282806, bbox_ratio: 0.4600715137067938
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8169845283976607, bbox_ratio: 0.4600715137067938
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1180958528350053, bbox_ratio: 0.4612634088200238
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8759811876268656, bbox_ratio: 0.46722288438617404
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4328913149457739, bbox_ratio: 0.46722288438617404
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7790984261781879, bbox_ratio: 0.4684147794994041
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.35562854644002984, bbox_ratio: 0.4654761904761905
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5631369903158129, bbox_ratio: 0.4625445897740785
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2227701115324876, bbox_ratio: 0.46135552913198574
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9928256586183433, bbox_ratio: 0.4637336504161712
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6370042597148176, bbox_ratio: 0.4684898929845422
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19499039912315963, bbox_ratio: 0.47268408551068886
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7944341452739785, bbox_ratio: 0.4709371293001186
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.161092138717522, bbox_ratio: 0.4591715976331361
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5147260564882873, bbox_ratio: 0.4591715976331361
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.501185990115534, bbox_ratio: 0.4491725768321513
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.433255521119223, bbox_ratio: 0.4414201183431953
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.523175680193976, bbox_ratio: 0.44166666666666665
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.699594627915719, bbox_ratio: 0.4803337306317044
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.405426210812518, bbox_ratio: 0.48862275449101794
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.449554933498419, bbox_ratio: 0.5215827338129496
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.597492253161698, bbox_ratio: 0.5378151260504201
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6763470725948415, bbox_ratio: 0.531812725090036
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.275478166336843, bbox_ratio: 0.5222088835534213
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.521258676305204, bbox_ratio: 0.4807692307692308
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.078179051925765, bbox_ratio: 0.4831325301204819
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.339657202272189, bbox_ratio: 0.4764776839565742
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8967192485014515, bbox_ratio: 0.4939613526570048
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8426766737673883, bbox_ratio: 0.5525997581620314
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.712434164755662, bbox_ratio: 0.5544794188861986
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.859112490426605, bbox_ratio: 0.572639225181598
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9448543190493158, bbox_ratio: 0.5871670702179177
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.31854045178011703, bbox_ratio: 0.5581113801452785
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.2371118337303273, bbox_ratio: 0.5084745762711864
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5819579374701631, bbox_ratio: 0.49575757575757573
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.160822838802864, bbox_ratio: 0.49514563106796117
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3989092062114479, bbox_ratio: 0.4921212121212121
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6186993721236339, bbox_ratio: 0.48727272727272725
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8456128527868462, bbox_ratio: 0.4830508474576271
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5968687392858655, bbox_ratio: 0.48184019370460046
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7660613698160025, bbox_ratio: 0.4782082324455206
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7193540847508207, bbox_ratio: 0.4703748488512696
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.676478405271327, bbox_ratio: 0.4727932285368803
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.20702422708486132, bbox_ratio: 0.4752116082224909
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2891232244120584, bbox_ratio: 0.47158403869407495
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.11700362219071152, bbox_ratio: 0.4794188861985472
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6116009133705361, bbox_ratio: 0.47699757869249393
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6741068315807591, bbox_ratio: 0.48
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6555042373049856, bbox_ratio: 0.47936893203883496
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.12684809140763126, bbox_ratio: 0.4787363304981774
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.20737176234603813, bbox_ratio: 0.5091130012150669
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2461085623802083, bbox_ratio: 0.5139732685297691
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.572063369853175, bbox_ratio: 0.5060679611650486
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1395235392634358, bbox_ratio: 0.49514563106796117
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3023568851906973, bbox_ratio: 0.4963592233009709
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4831363662522975, bbox_ratio: 0.5194174757281553
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.22430867644398836, bbox_ratio: 0.5527272727272727
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.674791590022845, bbox_ratio: 0.5575757575757576
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5826812749546258, bbox_ratio: 0.5624242424242424
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.23260701649618648, bbox_ratio: 0.5581113801452785
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.16700848766953097, bbox_ratio: 0.5508474576271186
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.19277858146113544, bbox_ratio: 0.5484261501210653
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.32634627491641804, bbox_ratio: 0.5447941888619855
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.17616613405755707, bbox_ratio: 0.5447941888619855
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.15122471342021346, bbox_ratio: 0.549636803874092
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.08134791555310251, bbox_ratio: 0.5484261501210653
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2619866339886533, bbox_ratio: 0.5520581113801453
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.24345730157682272, bbox_ratio: 0.5520581113801453
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5242167531852173, bbox_ratio: 0.5714285714285714
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.27468347036885693, bbox_ratio: 0.5835351089588378
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.35672565187386596, bbox_ratio: 0.5799031476997578
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6005335612879366, bbox_ratio: 0.576969696969697
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.22409245566299898, bbox_ratio: 0.5696969696969697
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2048927712447697, bbox_ratio: 0.5563636363636364
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3460303558064233, bbox_ratio: 0.5558252427184466
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3392840718653312, bbox_ratio: 0.5497572815533981
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2226584228049188, bbox_ratio: 0.5461165048543689
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.30715494356711515, bbox_ratio: 0.5455650060753341
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6601951358596136, bbox_ratio: 0.543134872417983
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5013298121582794, bbox_ratio: 0.5492102065613609
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.25452407080511946, bbox_ratio: 0.5407047387606319
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4649108186202166, bbox_ratio: 0.5334143377885784
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6897060153244834, bbox_ratio: 0.5273390036452005
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1395687030439288, bbox_ratio: 0.5296969696969697
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8794880469693831, bbox_ratio: 0.5309090909090909
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.230248735792915, bbox_ratio: 0.5478787878787879
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.9280954979215728, bbox_ratio: 0.5624242424242424
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9799902022537736, bbox_ratio: 0.5284848484848484
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.46516906626447, bbox_ratio: 0.47393939393939394
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.6573032845213898, bbox_ratio: 0.4641555285540705
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.314401540928885, bbox_ratio: 0.46650426309378806
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6745397493871663, bbox_ratio: 0.46650426309378806
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.5340250523407906, bbox_ratio: 0.47073170731707314
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.335501631728167, bbox_ratio: 0.47073170731707314
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.0203118650673515, bbox_ratio: 0.4609756097560976
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.991540810177227, bbox_ratio: 0.4652014652014652
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.572069569098506, bbox_ratio: 0.45787545787545786
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.109322945379431, bbox_ratio: 0.4511002444987775
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.699071169183851, bbox_ratio: 0.44621026894865523
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9328841755330017, bbox_ratio: 0.45843520782396086
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6057600967558189, bbox_ratio: 0.4511002444987775
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6180332476636397, bbox_ratio: 0.4541003671970624
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8894494382070177, bbox_ratio: 0.4557739557739558
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.855744269822257, bbox_ratio: 0.4567901234567901
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.258105201060976, bbox_ratio: 0.44801980198019803
# Predicted class: 0
# Predicted Class: 0
# Speed: 22.29564050884021, bbox_ratio: 0.4591584158415842
# Predicted class: 2
# Predicted Class: 2
# Speed: 28.380696690375462, bbox_ratio: 0.4937810945273632
# Predicted class: 2
# Predicted Class: 2
# Speed: 33.064678436967704, bbox_ratio: 0.6057213930348259
# Predicted class: 2
# Predicted Class: 2
# Speed: 30.889690884997485, bbox_ratio: 0.5149253731343284
# Predicted class: 2
# Predicted Class: 2
# Speed: 19.54618886959233, bbox_ratio: 0.4962686567164179
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.838213644054711, bbox_ratio: 0.5167701863354037
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.544483779664029, bbox_ratio: 0.47896039603960394
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.705169525008813, bbox_ratio: 0.5080346106304079
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.678069135378673, bbox_ratio: 0.47901234567901235
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.313715530475259, bbox_ratio: 0.4759556103575832
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.071457981351934, bbox_ratio: 0.4777777777777778
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.7046733182766705, bbox_ratio: 0.49133663366336633
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.9511372124849595, bbox_ratio: 0.48009950248756217
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.904198983046497, bbox_ratio: 0.4794520547945205
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.453187578909878, bbox_ratio: 0.46441947565543074
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.361926864622689, bbox_ratio: 0.45431789737171463
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.96292391940423, bbox_ratio: 0.4440251572327044
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.291539014937648, bbox_ratio: 0.4401008827238335
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.011908214385091, bbox_ratio: 0.4361567635903919
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.1294604514738715, bbox_ratio: 0.5139240506329114
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.3169324964514667, bbox_ratio: 0.5177215189873418
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.350481680934854, bbox_ratio: 0.549936788874842
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4541747317497908, bbox_ratio: 0.5366161616161617
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.6155483529220678, bbox_ratio: 0.5629722921914357
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6247824673553084, bbox_ratio: 0.5440806045340051
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2303118170945053, bbox_ratio: 0.5350877192982456
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.092062042143241, bbox_ratio: 0.487468671679198
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.379946148110701, bbox_ratio: 0.5031289111389237
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.529605240132142, bbox_ratio: 0.52375
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.141603735863159, bbox_ratio: 0.4962686567164179
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.872601461997558, bbox_ratio: 0.5677018633540373
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.235293825543783, bbox_ratio: 0.543424317617866
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.7961068565127825, bbox_ratio: 0.5583126550868487
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.11252810367964, bbox_ratio: 0.45781637717121587
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8100047579085894, bbox_ratio: 0.45285359801488834
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3504803033711898, bbox_ratio: 0.45217391304347826
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4691202766521079, bbox_ratio: 0.4551122194513716
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.608469217231264, bbox_ratio: 0.45603015075376885
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.841993916741054, bbox_ratio: 0.450063211125158
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.394097686419395, bbox_ratio: 0.44726810673443457
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.748255801341495, bbox_ratio: 0.4413265306122449
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.1671984542567952, bbox_ratio: 0.4309462915601023
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.543174109267674, bbox_ratio: 0.4159178433889602
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.904372183409816, bbox_ratio: 0.41516709511568123
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.9699640484270464, bbox_ratio: 0.4072164948453608
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.075992405412894, bbox_ratio: 0.40516129032258064
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.051567076936376, bbox_ratio: 0.4069767441860465
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.182558825703635, bbox_ratio: 0.42248062015503873
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.359483017625843, bbox_ratio: 0.417312661498708
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.617053978209471, bbox_ratio: 0.40335051546391754
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.836099477661577, bbox_ratio: 0.38382541720154045
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.532054862672236, bbox_ratio: 0.35723431498079383
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.28490728549062, bbox_ratio: 0.34271099744245526
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.49266459579921, bbox_ratio: 0.34398976982097185
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.764221980906071, bbox_ratio: 0.30434782608695654
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.96733371800903, bbox_ratio: 0.29411764705882354
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7324822210942035, bbox_ratio: 0.2915601023017903
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41674876654721466, bbox_ratio: 0.3128991060025543
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.0505646020482178, bbox_ratio: 0.29449423815621
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0636446273180913, bbox_ratio: 0.30089628681177977
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.9430424109286046, bbox_ratio: 0.30512820512820515
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.11668258491032, bbox_ratio: 0.3072983354673495
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.3831095127964568, bbox_ratio: 0.30818414322250637
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.8537224125545864, bbox_ratio: 0.3086734693877551
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4573922410163764, bbox_ratio: 0.30661577608142493
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.248215733318898, bbox_ratio: 0.30583756345177665
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.330079698195512, bbox_ratio: 0.3050632911392405
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.304437712987705, bbox_ratio: 0.3035264483627204
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.001322494111161, bbox_ratio: 0.30402010050251255
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.896516422468668, bbox_ratio: 0.2961104140526976
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.806893961129637, bbox_ratio: 0.29448621553884713
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.2751334986546574, bbox_ratio: 0.28858218318695106
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.485804991070173, bbox_ratio: 0.28732747804265996
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.975324875908632, bbox_ratio: 0.2860727728983689
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1723393030054619, bbox_ratio: 0.2860727728983689
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2178456191938323, bbox_ratio: 0.28732747804265996
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.8601898616483696, bbox_ratio: 0.2936010037641154
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.50749668350643, bbox_ratio: 0.30112923462986196
# Predicted class: 2
# Predicted Class: 2
# Speed: 15.671112715461648, bbox_ratio: 0.3111668757841907
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.405162623635146, bbox_ratio: 0.3241206030150754
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.430004973391139, bbox_ratio: 0.34465408805031444
# Predicted class: 0
# Predicted Class: 0
# Speed: 19.639249000446114, bbox_ratio: 0.3555276381909548
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.71731840769668, bbox_ratio: 0.38567839195979897
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.744251214641473, bbox_ratio: 0.39724310776942356
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.796472707500183, bbox_ratio: 0.40375
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.933139199793892, bbox_ratio: 0.42
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.630930268855417, bbox_ratio: 0.435
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.469015921146287, bbox_ratio: 0.4475
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.097501289361194, bbox_ratio: 0.45056320400500627
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.071367200169004, bbox_ratio: 0.449874686716792
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.57809149845313, bbox_ratio: 0.44360902255639095
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.414209610098942, bbox_ratio: 0.43734335839599
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.49648148932366, bbox_ratio: 0.4448574969021066
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.4563883221873, bbox_ratio: 0.4601226993865031
# Predicted class: 0
# Predicted Class: 0
# Speed: 21.802390522808867, bbox_ratio: 0.4841075794621027
# Predicted class: 2
# Predicted Class: 2
# Speed: 32.578101253119485, bbox_ratio: 0.6105006105006106
# Predicted class: 2
# Predicted Class: 2
# Speed: 49.22219774618705, bbox_ratio: 0.5598548972188634
# Predicted class: 1
# Predicted Class: 1
# Speed: 80.78517054733545, bbox_ratio: 0.633769322235434
# Predicted class: 1
# Predicted Class: 1
# Speed: 104.11105156182599, bbox_ratio: 0.6206896551724138
# Predicted class: 1
# Predicted Class: 1
# Speed: 132.33672977441498, bbox_ratio: 0.6998556998556998
# Predicted class: 1
# Predicted Class: 1
# Speed: 137.2447779109764, bbox_ratio: 1.0396975425330812
# Predicted class: 1
# Predicted Class: 1
# Speed: 104.4976825736928, bbox_ratio: 1.1206896551724137
# Predicted class: 1
# Predicted Class: 1
# Speed: 76.88976576274986, bbox_ratio: 1.8094117647058823
# Predicted class: 1
# Predicted Class: 1
# Speed: 55.83995983998178, bbox_ratio: 1.8037383177570094
# Predicted class: 1
# Predicted Class: 1
# Speed: 64.7541410987891, bbox_ratio: 1.817102137767221
# Predicted class: 1
# Predicted Class: 1
# Speed: 81.78458804698303, bbox_ratio: 1.6085918854415275
# Predicted class: 1
# Predicted Class: 1
# Speed: 39.840608254372064, bbox_ratio: 1.1655913978494623
# Predicted class: 1
# Predicted Class: 1
# Speed: 77.49182313001894, bbox_ratio: 1.064102564102564
# Predicted class: 1
# Predicted Class: 1
# Speed: 75.48556294120641, bbox_ratio: 0.8711180124223602
# Predicted class: 1
# Predicted Class: 1
# Speed: 88.44650665225541, bbox_ratio: 0.7551867219917012
# Predicted class: 1
# Predicted Class: 1
# Speed: 73.42414263754299, bbox_ratio: 0.8059895833333334
# Predicted class: 1
# Predicted Class: 1
# Speed: 53.12458739563883, bbox_ratio: 0.8403990024937655
# Predicted class: 1
# Predicted Class: 1
# Speed: 37.53649313298453, bbox_ratio: 0.8317307692307693
# Predicted class: 2
# Predicted Class: 2
# Speed: 40.29534025422939, bbox_ratio: 0.7751141552511416
# Predicted class: 2
# Predicted Class: 2
# Speed: 38.793639842518154, bbox_ratio: 0.8329694323144105
# Predicted class: 2
# Predicted Class: 2
# Speed: 37.5433878271126, bbox_ratio: 0.8768267223382046
# Predicted class: 2
# Predicted Class: 2
# Speed: 25.062349303162033, bbox_ratio: 0.9298067141403866
# Predicted class: 2
# Predicted Class: 2
# Speed: 27.923207507856947, bbox_ratio: 0.954728370221328
# Predicted class: 2
# Predicted Class: 2
# Speed: 23.27260257505292, bbox_ratio: 0.938508064516129
# Predicted class: 2
# Predicted Class: 2
# Speed: 45.33890921012549, bbox_ratio: 0.9536082474226805
# Predicted class: 1
# Predicted Class: 1
# Speed: 49.09054476628749, bbox_ratio: 0.9205851619644723
# Predicted class: 1
# Predicted Class: 1
# Speed: 64.26409711523803, bbox_ratio: 0.9014830508474576
# Predicted class: 1
# Predicted Class: 1
# Speed: 53.248959289886066, bbox_ratio: 0.8739224137931034
# Predicted class: 1
# Predicted Class: 1
# Speed: 57.39784352572921, bbox_ratio: 1.176278563656148
# Predicted class: 1
# Predicted Class: 1
# Speed: 47.66863237683575, bbox_ratio: 0.9662309368191722
# Predicted class: 1
# Predicted Class: 1
# Speed: 38.095479420214936, bbox_ratio: 1.1193370165745857
# Predicted class: 1
# Predicted Class: 1
# Speed: 31.60389628973918, bbox_ratio: 1.0449438202247192
# Predicted class: 1
# Predicted Class: 1
# Speed: 25.556895288915204, bbox_ratio: 1.0739476678043232
# Predicted class: 1
# Predicted Class: 1
# Speed: 21.420389244307174, bbox_ratio: 1.1668584579976986
# Predicted class: 1
# Predicted Class: 1
# Speed: 21.78655649059887, bbox_ratio: 1.2277456647398843
# Predicted class: 1
# Predicted Class: 1
# Speed: 14.545809698103177, bbox_ratio: 1.439306358381503
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.436640107583356, bbox_ratio: 1.499421965317919
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.788228235288603, bbox_ratio: 1.4780600461893765
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.80390997147217, bbox_ratio: 1.4429065743944636
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.302949900656692, bbox_ratio: 1.408675799086758
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.759718395852671, bbox_ratio: 1.3573033707865167
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.300866036222903, bbox_ratio: 1.3116022099447513
# Predicted class: 1
# Predicted Class: 1
# Speed: 18.119939240745584, bbox_ratio: 1.2396514161220045
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.412463553930447, bbox_ratio: 1.1883745963401506
# Predicted class: 0
# Predicted Class: 0
# Speed: 28.103628936146777, bbox_ratio: 1.1318327974276527
# Predicted class: 1
# Predicted Class: 1
# Speed: 12.683862637648055, bbox_ratio: 1.0642398286937902
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.922840649881747, bbox_ratio: 1.0128755364806867
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.71327745933483, bbox_ratio: 1.0053648068669527
# Predicted class: 0
# Predicted Class: 0
# Speed: 25.024986575304236, bbox_ratio: 0.9785407725321889
# Predicted class: 2
# Predicted Class: 2
# Speed: 26.78799888658604, bbox_ratio: 0.916219119226638
# Predicted class: 2
# Predicted Class: 2
# Speed: 21.579320251388335, bbox_ratio: 0.8711063372717508
# Predicted class: 2
# Predicted Class: 2
# Speed: 16.43364870257342, bbox_ratio: 0.8365800865800865
# Predicted class: 0
# Predicted Class: 0
# Speed: 21.492621365262867, bbox_ratio: 0.7141304347826087
# Predicted class: 2
# Predicted Class: 2
# Speed: 15.322855133651169, bbox_ratio: 0.6758241758241759
# Predicted class: 0
# Predicted Class: 0
# Speed: 18.46228277853637, bbox_ratio: 0.49171270718232046
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.90766380361717, bbox_ratio: 0.5975609756097561
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.191826673446478, bbox_ratio: 0.5862068965517241
# Predicted class: 0
# Predicted Class: 0
# Speed: 15.898429602287065, bbox_ratio: 0.5389755011135857
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.875233895994343, bbox_ratio: 0.5426966292134832
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.237322213149367, bbox_ratio: 0.4532130777903044
# Predicted class: 0
# Predicted Class: 0
# Speed: 20.458360786757968, bbox_ratio: 0.5213963963963963
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.918639278191474, bbox_ratio: 0.4858757062146893
# Predicted class: 2
# Predicted Class: 2
# Speed: 22.28457058836202, bbox_ratio: 0.48361581920903957
# Predicted class: 2
# Predicted Class: 2
# Speed: 13.653467570507093, bbox_ratio: 0.44280860702151753
# Predicted class: 0
# Predicted Class: 0
# Speed: 38.20692130372181, bbox_ratio: 0.4532130777903044
# Predicted class: 2
# Predicted Class: 2
# Speed: 29.010939283350446, bbox_ratio: 0.37232845894263217
# Predicted class: 2
# Predicted Class: 2
# Speed: 21.898660797730336, bbox_ratio: 0.3678290213723285
# Predicted class: 2
# Predicted Class: 2
# Speed: 19.095991022255618, bbox_ratio: 0.3811659192825112
# Predicted class: 0
# Predicted Class: 0
# Speed: 24.996059797373793, bbox_ratio: 0.371523915461624
# Predicted class: 2
# Predicted Class: 2
# Speed: 15.105678672304146, bbox_ratio: 0.3762486126526082
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.032756316047077, bbox_ratio: 0.311529933481153
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.337295039854324, bbox_ratio: 0.3208791208791209
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.8155429031791301, bbox_ratio: 0.33223322332233224
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.001249136692312, bbox_ratio: 0.35973597359735976
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.653137798817813, bbox_ratio: 0.3256325632563256
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.492870189312223, bbox_ratio: 0.343646408839779
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.181709045582815, bbox_ratio: 0.301218161683278
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.02962655622376, bbox_ratio: 0.27111111111111114
# Predicted class: 0
# Predicted Class: 0
# Speed: 14.413607598372344, bbox_ratio: 0.2857142857142857
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.826734261463459, bbox_ratio: 0.2855543113101904
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.721341759067188, bbox_ratio: 0.2878103837471783
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.7927588153671605, bbox_ratio: 0.2818181818181818
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6731246999076377, bbox_ratio: 0.27366020524515394
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.18190907845732, bbox_ratio: 0.27262313860252
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.916370307045266, bbox_ratio: 0.37155963302752293
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.87950722290269, bbox_ratio: 0.32873563218390806
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.709344882746833, bbox_ratio: 0.42117376294591485
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.260800661180753, bbox_ratio: 0.46835443037974683
# Predicted class: 0
# Predicted Class: 0
# Speed: 6.64227218488267, bbox_ratio: 0.5212888377445339
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.800711647804059, bbox_ratio: 0.49252013808975836
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.270794380558183, bbox_ratio: 0.41446613088404133
# Predicted class: 0
# Predicted Class: 0
# Speed: 10.387841231643957, bbox_ratio: 0.4009163802978236
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.696650141853647, bbox_ratio: 0.45485714285714285
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.7525089623182977, bbox_ratio: 0.4444444444444444
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.489649266983017, bbox_ratio: 0.4334862385321101
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.139202355997432, bbox_ratio: 0.42201834862385323
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.171678436816883, bbox_ratio: 0.39862542955326463
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.3016967735176768, bbox_ratio: 0.48911798396334477
# Predicted class: 0
# Predicted Class: 0
# Speed: 2.2195088060934913, bbox_ratio: 0.4954128440366973
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.6534426445456893, bbox_ratio: 0.5104408352668214
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.451286305505834, bbox_ratio: 0.5110081112398609
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8637600825987826, bbox_ratio: 0.5133565621370499
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.081432838220994, bbox_ratio: 0.463785046728972
# Predicted class: 0
# Predicted Class: 0
# Speed: 13.099854984991074, bbox_ratio: 0.46776084407971863
# Predicted class: 0
# Predicted Class: 0
# Speed: 12.719730732354982, bbox_ratio: 0.48413631022326675
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.4655432642256, bbox_ratio: 0.4835294117647059
# Predicted class: 0
# Predicted Class: 0
# Speed: 7.704600192027252, bbox_ratio: 0.52
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.014729823850948, bbox_ratio: 0.5047058823529412
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.0018249045445557, bbox_ratio: 0.5105882352941177
# Predicted class: 0
# Predicted Class: 0
# Speed: 4.562314792435456, bbox_ratio: 0.5129411764705882
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.458549990535296, bbox_ratio: 0.5111896348645465
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.1141957887588108, bbox_ratio: 0.5041224970553593
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5527527557820833, bbox_ratio: 0.4988207547169811
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4693762008099003, bbox_ratio: 0.44693396226415094
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5413433127880961, bbox_ratio: 0.44457547169811323
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.7784210237538349, bbox_ratio: 0.44457547169811323
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.41295304143171035, bbox_ratio: 0.4628099173553719
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.13789731629841043, bbox_ratio: 0.45336481700118064
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.45772913591577535, bbox_ratio: 0.4675324675324675
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.6013765717845351, bbox_ratio: 0.4722550177095632
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5582395477824712, bbox_ratio: 0.4781582054309327
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.949072027944751, bbox_ratio: 0.4811320754716981
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.24563375924588768, bbox_ratio: 0.45218417945690675
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2752380450993977, bbox_ratio: 0.4386792452830189
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.5343798647300715, bbox_ratio: 0.43580683156654887
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.4474987445239512, bbox_ratio: 0.43109540636042404
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.1292309309422519, bbox_ratio: 0.43109540636042404
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.28428241158220835, bbox_ratio: 0.4329411764705882
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.2221104464319292, bbox_ratio: 0.4418331374853114
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9008731210195265, bbox_ratio: 0.4406580493537015
# Predicted class: 0
# Predicted Class: 0
# Speed: 0.9182055124086304, bbox_ratio: 0.4471830985915493
# Predicted class: 0
# Predicted Class: 0
# Speed: 5.305703513142623, bbox_ratio: 0.458041958041958
# Predicted class: 0
# Predicted Class: 0
# Speed: 9.82567163945583, bbox_ratio: 0.48839907192575405
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.538658382765465, bbox_ratio: 0.5052143684820394
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.720384676933026, bbox_ratio: 0.49479768786127165
# Predicted class: 0
# Predicted Class: 0
# Speed: 17.168421102158728, bbox_ratio: 0.48105625717566014
# Predicted class: 0
# Predicted Class: 0
# Speed: 16.542864190207812, bbox_ratio: 0.4833906071019473
# Predicted class: 0
# Predicted Class: 0
# Speed: 8.51789477887041, bbox_ratio: 0.5085714285714286
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.4973959044919862, bbox_ratio: 0.5255972696245734
# Predicted class: 0
# Predicted Class: 0
# Speed: 3.8083699262992265, bbox_ratio: 0.5208098987626547
# Predicted class: 0
# Predicted Class: 0
# Speed: 1.7747890040107872, bbox_ratio: 0.5067415730337078
# Predicted class: 0
# Predicted Class: 0
# Speed: 11.434411747580553, bbox_ratio: 0.4871508379888268
# Predicted class: 0
# Predicted Class: 0
# Speed: 27.884863439175078, bbox_ratio: 0.5100222717149221
# Predicted class: 2
# Predicted Class: 2
# Speed: 42.442211879675554, bbox_ratio: 0.5929203539823009
# Predicted class: 1
# Predicted Class: 1
# Speed: 55.65026806524591, bbox_ratio: 0.6214750542299349
# Predicted class: 1
# Predicted Class: 1
# Speed: 46.14240655044536, bbox_ratio: 0.6274921301154249
# Predicted class: 1
# Predicted Class: 1
# Speed: 46.6516818601699, bbox_ratio: 0.6752049180327869
# Predicted class: 1
# Predicted Class: 1
# Speed: 44.105018744044564, bbox_ratio: 0.6626262626262627
# Predicted class: 1
# Predicted Class: 1
# Speed: 28.533054836100355, bbox_ratio: 0.5711361310133061
# Predicted class: 2
# Predicted Class: 2
# Speed: 68.16435497353385, bbox_ratio: 0.26789366053169733
# Predicted class: 1
# Predicted Class: 1
# Speed: 73.29139577845665, bbox_ratio: 0.2108050847457627
# Predicted class: 1
# Predicted Class: 1
# -1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

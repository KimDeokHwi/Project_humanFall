# %% [markdown]
# ## mediapipe 랜드마크만 학습
# * 정의된 랜드마크(11개)만 학습
# * input_size = 22

# %%
import os
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import cv2
import mediapipe as mp
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, confusion_matrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### GRU training

# %%
# 랜드마크 인덱스 정의
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# 데이터셋 클래스 정의
class FallSequenceDataset(Dataset):
    def __init__(self, json_files, sequence_length=3):
        self.sequence_length = sequence_length
        self.sequences = []
        self.labels = []
        self.scaler = StandardScaler()
        all_landmarks = []  # 리스트 초기화
        print(f"LANDMARKS len :{len(LANDMARKS)}")
      
        for json_file in json_files:
            print(f'Processing file: {json_file}')
            with open(json_file, 'r') as f:
                data = json.load(f)
        
            frames = list(data['pose_data'].values())
        
            for i in range(0, len(frames) - self.sequence_length + 1):
                sequence = frames[i:i+self.sequence_length]
                landmarks = []
                fall_frames = 0  
               
                for frame in sequence:
                    frame_landmarks = []
                    for landmark in LANDMARKS:
                        if f'landmark_{landmark}' not in frame:
                            print(f"Missing landmark {landmark} in frame")
                            continue
                        frame_landmarks.extend([
                            frame[f'landmark_{landmark}']['x'],
                            frame[f'landmark_{landmark}']['y']
                            ])
                    landmarks.append(frame_landmarks)
                    all_landmarks.append(frame_landmarks)  # 리스트에 추가
                    if frame['class'] == 'Fall':  # fall_frames 계산
                        fall_frames += 1
                               
                self.sequences.append(landmarks)
                self.labels.append(self.define_label(fall_frames))  # label 정의
    
        # 전체 데이터 정규화 (모든 시퀀스 처리 후)
        if all_landmarks:
            all_landmarks = np.array(all_landmarks)  # NumPy 배열로 변환
            all_landmarks_scaled = self.scaler.fit_transform(all_landmarks)

            # 정규화된 데이터를 다시 시퀀스로 재구성
            for i in range(len(self.sequences)):
                start = i * self.sequence_length
                end = start + self.sequence_length
                self.sequences[i] = all_landmarks_scaled[start:end]
                
        if not self.sequences:
            raise ValueError("시퀀스 없음")
        
    def define_label(self, fall_frames):
        if fall_frames == 0:
            return 0  # 비낙상
        elif fall_frames == self.sequence_length:
            return 2  # 완전 낙상
        else:
            return 1  # 낙상 위험

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        if idx >= len(self.sequences):
            raise IndexError(f"Index {idx} out of range. Dataset length: {len(self.sequences)}")
                
        sequence = np.array(self.sequences[idx])
        return torch.FloatTensor(sequence), torch.LongTensor([self.labels[idx]]).squeeze()

# GRU 모델 정의
class FallDetectionGRU(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, output_size=3, dropout = 0.5):
        super(FallDetectionGRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout = dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[ : , -1, :])
        out = self.fc(out)
        return out

# 데이터 로드 및 전처리
json_folder = 'D:\\human_fall\\re_landmark\\addition_yolobbox_json_6'
json_files = [os.path.join(json_folder, f) for f in os.listdir(json_folder) if f.endswith('.json')]
dataset = FallSequenceDataset(json_files)

# 데이터셋을 학습 및 검증 세트로 분할
train_indices, val_indices = train_test_split(range(len(dataset)), test_size=0.2)
train_dataset = torch.utils.data.Subset(dataset, train_indices)
val_dataset = torch.utils.data.Subset(dataset, val_indices)

# 데이터 로더 생성 전 클래스 가중치 계산
train_labels = np.array([label for _, label in train_dataset], dtype=int)
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weights = torch.FloatTensor(class_weights).to(device)

# 손실 함수에 가중치 적용
criterion = nn.CrossEntropyLoss(weight=class_weights)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

if len(dataset) > 0:
    sample_sequence, sample_label = dataset[0]
    input_size = sample_sequence.shape[1]
    print(f'input_size :{input_size}')
    model = FallDetectionGRU(input_size).to(device)
else:
    print("데이터 없음")
    exit()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001,  weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
num_epochs = 500
best_loss = float('inf')
patience = 15
no_improve = 0

for epoch in range(num_epochs):
    model.train()
    total_loss_train = 0
    
    for sequences, labels in train_loader:
        sequences, labels = sequences.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(sequences)
        loss_train = criterion(outputs, labels.view(-1))
        loss_train.backward()
        optimizer.step()
        
        total_loss_train += loss_train.item()
    
    avg_loss_train = total_loss_train / len(train_loader)

    # 검증 단계 추가
    model.eval()
    total_loss_val = 0
    
    with torch.no_grad():
        for sequences_val, labels_val in val_loader:
            sequences_val, labels_val = sequences_val.to(device), labels_val.to(device)
            outputs_val = model(sequences_val)
            loss_val = criterion(outputs_val, labels_val.view(-1))
            total_loss_val += loss_val.item()
    
    avg_loss_val = total_loss_val / len(val_loader)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss_train:.4f}, Val Loss: {avg_loss_val:.4f}')
    scheduler.step(avg_loss_val)
    
    if avg_loss_val < best_loss:
        best_loss = avg_loss_val
        no_improve = 0
        torch.save(model.state_dict(), 'only_mediapipe.pt')
    else:
        no_improve += 1
    
    if no_improve >= patience:
        print("Early stopping")
        break
    
def calculate_metrics(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for sequences, labels in data_loader:
            sequences, labels = sequences.to(device), labels.to(device)
            outputs = model(sequences)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    f1 = f1_score(all_labels, all_preds, average='weighted')
    cm = confusion_matrix(all_labels, all_preds)
    return f1, cm

# 학습 루프 내에서 성능 지표 계산
train_f1, train_cm = calculate_metrics(model, train_loader)
val_f1, val_cm = calculate_metrics(model, val_loader)
print(f'Train F1: {train_f1:.4f}, Val F1: {val_f1:.4f}')
print(f'Train CM:\n{train_cm}\nVal CM:\n{val_cm}')

print("Training completed")

# F1 스코어와 혼동 행렬을 파일로 저장
def save_metrics(f1_train, cm_train, f1_val, cm_val, file_path='only_mediapipe.pt.txt'):
    with open(file_path, 'w') as f:
        f.write(f'Train F1: {f1_train:.4f}\n')
        f.write(f'Val F1: {f1_val:.4f}\n')
        f.write(f'Train Confusion Matrix:\n{cm_train}\n')
        f.write(f'Val Confusion Matrix:\n{cm_val}\n')

# 결과 저장
save_metrics(train_f1, train_cm, val_f1, val_cm, file_path='only_mediapipe.pt.txt')

print("저장 완료")
# Out:
# LANDMARKS len :11
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00060_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00093_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00096_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00108_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00112_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00114_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00121_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00130_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00132_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00158_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00164_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00171_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00172_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00174_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00175_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00188_H_A_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00191_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00193_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00194_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00247_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00258_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00265_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00269_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00291_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00299_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00302_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00323_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00341_H_A_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00478_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00480_H_A_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00486_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00505_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00526_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00533_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00548_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00574_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00593_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00596_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00615_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00619_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00665_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00676_H_D_SY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00690_H_D_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00704_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00705_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00707_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00712_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00737_H_D_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00751_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00758_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00777_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00788_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00792_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00799_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00815_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00864_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00867_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00879_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00888_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00896_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00902_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00945_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00969_O_E_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00983_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\00998_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01006_O_E_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01054_O_E_N_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01089_O_E_N_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01089_O_E_N_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01089_O_E_N_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\01089_O_E_N_C4.json
# ...
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02735_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02735_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02735_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02735_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02735_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02742_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02786_H_A_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02805_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02813_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02821_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02830_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02844_H_D_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02871_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02874_H_C_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02879_H_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02900_Y_C_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02961_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02966_L_F_BY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02969_L_F_FY_C8.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C1.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C2.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C3.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C4.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C5.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C6.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C7.json
# Processing file: D:\human_fall\re_landmark\addition_yolobbox_json_6\02970_L_F_FY_C8.json
# input_size :22
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch [1/500], Train Loss: 0.3317, Val Loss: 0.2845
# Epoch [2/500], Train Loss: 0.2824, Val Loss: 0.2521
# Epoch [3/500], Train Loss: 0.2552, Val Loss: 0.2295
# Epoch [4/500], Train Loss: 0.2389, Val Loss: 0.2166
# Epoch [5/500], Train Loss: 0.2246, Val Loss: 0.2055
# Epoch [6/500], Train Loss: 0.2146, Val Loss: 0.1948
# Epoch [7/500], Train Loss: 0.2059, Val Loss: 0.1832
# Epoch [8/500], Train Loss: 0.1997, Val Loss: 0.1815
# Epoch [9/500], Train Loss: 0.1939, Val Loss: 0.1709
# Epoch [10/500], Train Loss: 0.1877, Val Loss: 0.1741
# Epoch [11/500], Train Loss: 0.1834, Val Loss: 0.1653
# Epoch [12/500], Train Loss: 0.1789, Val Loss: 0.1609
# Epoch [13/500], Train Loss: 0.1756, Val Loss: 0.1588
# Epoch [14/500], Train Loss: 0.1721, Val Loss: 0.1601
# Epoch [15/500], Train Loss: 0.1678, Val Loss: 0.1531
# Epoch [16/500], Train Loss: 0.1651, Val Loss: 0.1519
# Epoch [17/500], Train Loss: 0.1621, Val Loss: 0.1497
# Epoch [18/500], Train Loss: 0.1600, Val Loss: 0.1483
# Epoch [19/500], Train Loss: 0.1592, Val Loss: 0.1493
# Epoch [20/500], Train Loss: 0.1553, Val Loss: 0.1440
# Epoch [21/500], Train Loss: 0.1540, Val Loss: 0.1423
# Epoch [22/500], Train Loss: 0.1516, Val Loss: 0.1470
# Epoch [23/500], Train Loss: 0.1504, Val Loss: 0.1422
# Epoch [24/500], Train Loss: 0.1476, Val Loss: 0.1399
# Epoch [25/500], Train Loss: 0.1465, Val Loss: 0.1389
# Epoch [26/500], Train Loss: 0.1438, Val Loss: 0.1368
# Epoch [27/500], Train Loss: 0.1431, Val Loss: 0.1367
# Epoch [28/500], Train Loss: 0.1413, Val Loss: 0.1366
# Epoch [29/500], Train Loss: 0.1401, Val Loss: 0.1390
# Epoch [30/500], Train Loss: 0.1384, Val Loss: 0.1419
# Epoch [31/500], Train Loss: 0.1380, Val Loss: 0.1378
# Epoch [32/500], Train Loss: 0.1356, Val Loss: 0.1328
# Epoch [33/500], Train Loss: 0.1346, Val Loss: 0.1324
# Epoch [34/500], Train Loss: 0.1349, Val Loss: 0.1306
# Epoch [35/500], Train Loss: 0.1314, Val Loss: 0.1295
# Epoch [36/500], Train Loss: 0.1311, Val Loss: 0.1296
# Epoch [37/500], Train Loss: 0.1292, Val Loss: 0.1317
# Epoch [38/500], Train Loss: 0.1295, Val Loss: 0.1291
# Epoch [39/500], Train Loss: 0.1287, Val Loss: 0.1312
# Epoch [40/500], Train Loss: 0.1266, Val Loss: 0.1283
# Epoch [41/500], Train Loss: 0.1265, Val Loss: 0.1331
# Epoch [42/500], Train Loss: 0.1249, Val Loss: 0.1318
# Epoch [43/500], Train Loss: 0.1253, Val Loss: 0.1352
# Epoch [44/500], Train Loss: 0.1246, Val Loss: 0.1226
# Epoch [45/500], Train Loss: 0.1227, Val Loss: 0.1309
# Epoch [46/500], Train Loss: 0.1231, Val Loss: 0.1254
# Epoch [47/500], Train Loss: 0.1213, Val Loss: 0.1240
# Epoch [48/500], Train Loss: 0.1201, Val Loss: 0.1224
# Epoch [49/500], Train Loss: 0.1204, Val Loss: 0.1242
# Epoch [50/500], Train Loss: 0.1191, Val Loss: 0.1220
# Epoch [51/500], Train Loss: 0.1191, Val Loss: 0.1233
# Epoch [52/500], Train Loss: 0.1181, Val Loss: 0.1240
# Epoch [53/500], Train Loss: 0.1182, Val Loss: 0.1271
# Epoch [54/500], Train Loss: 0.1165, Val Loss: 0.1276
# Epoch [55/500], Train Loss: 0.1167, Val Loss: 0.1261
# Epoch [56/500], Train Loss: 0.1162, Val Loss: 0.1248
# Epoch [57/500], Train Loss: 0.1013, Val Loss: 0.1148
# Epoch [58/500], Train Loss: 0.0978, Val Loss: 0.1138
# Epoch [59/500], Train Loss: 0.0962, Val Loss: 0.1147
# Epoch [60/500], Train Loss: 0.0960, Val Loss: 0.1138
# Epoch [61/500], Train Loss: 0.0949, Val Loss: 0.1153
# Epoch [62/500], Train Loss: 0.0948, Val Loss: 0.1138
# Epoch [63/500], Train Loss: 0.0949, Val Loss: 0.1139
# Epoch [64/500], Train Loss: 0.0938, Val Loss: 0.1137
# Epoch [65/500], Train Loss: 0.0929, Val Loss: 0.1137
# Epoch [66/500], Train Loss: 0.0922, Val Loss: 0.1135
# Epoch [67/500], Train Loss: 0.0925, Val Loss: 0.1121
# Epoch [68/500], Train Loss: 0.0923, Val Loss: 0.1137
# Epoch [69/500], Train Loss: 0.0923, Val Loss: 0.1130
# Epoch [70/500], Train Loss: 0.0919, Val Loss: 0.1138
# Epoch [71/500], Train Loss: 0.0915, Val Loss: 0.1144
# Epoch [72/500], Train Loss: 0.0911, Val Loss: 0.1139
# Epoch [73/500], Train Loss: 0.0906, Val Loss: 0.1145
# Epoch [74/500], Train Loss: 0.0889, Val Loss: 0.1135
# Epoch [75/500], Train Loss: 0.0892, Val Loss: 0.1132
# Epoch [76/500], Train Loss: 0.0896, Val Loss: 0.1136
# Epoch [77/500], Train Loss: 0.0891, Val Loss: 0.1129
# Epoch [78/500], Train Loss: 0.0892, Val Loss: 0.1132
# Epoch [79/500], Train Loss: 0.0891, Val Loss: 0.1134
# Epoch [80/500], Train Loss: 0.0886, Val Loss: 0.1134
# Epoch [81/500], Train Loss: 0.0888, Val Loss: 0.1133
# Epoch [82/500], Train Loss: 0.0881, Val Loss: 0.1133
# Early stopping
# Train F1: 0.9703, Val F1: 0.9608
# Train CM:
# [[90360    79   837]
#  [  663   172  1330]
#  [  400    59 45366]]
# Val CM:
# [[22502    21   388]
#  [  174    16   345]
#  [  194    35 11142]]
# Training completed
# 저장 완료

# %% [markdown]
# ### video 파일로 테스트 및 저장

# %%
LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# GRU 모델 정의
class FallDetectionGRU(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, output_size=3, dropout = 0.5):
        super(FallDetectionGRU, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout = dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[ : , -1, :])
        out = self.fc(out)
        return out

# %%
# 모델 로드 함수
def load_model(model_path, input_size):
    model = FallDetectionGRU(input_size).to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

# Mediapipe Pose 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)
LABELS = {0: 'Normal', 1: 'Fall', 2: 'Danger'}

def process_video(video_path, model, output_path):
    cap = cv2.VideoCapture(video_path)
    
    # 비디오 속성 가져오기
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # VideoWriter 초기화
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  
    out = cv2.VideoWriter(output_path, fourcc, fps, (1920, 1080))

    predictions = []
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # BGR to RGB
        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        # 랜드마크가 존재하는 경우에만 처리
        if results.pose_landmarks:
            landmarks = extract_landmarks(results)
            if len(landmarks) < len(LANDMARKS):  # 랜드마크 수가 부족한 경우 처리
                # 부족한 랜드마크에 대해 패딩 추가 (0으로 채우기)
                while len(landmarks) < len(LANDMARKS):
                    landmarks.append([0, 0])  # 기본값으로 (0, 0) 추가
            
            # 시퀀스 형식으로 변환
            sequence = np.array(landmarks).reshape(1, -1, input_size)  # (1, sequence_length, input_size)
            sequence_tensor = torch.FloatTensor(sequence).to(device)

            with torch.no_grad():
                output = model(sequence_tensor)
                _, predicted_class = torch.max(output, 1)
                predictions.append(predicted_class.item())

            # 예측 클래스를 비디오 프레임에 표시
            label = LABELS[predicted_class.item()]
            cv2.putText(frame, f'GRU pred :{label}', (10, 80),
                        cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 3)

            # 랜드마크 그리기
            mp.solutions.drawing_utils.draw_landmarks(frame, results.pose_landmarks,
                                                       mp_pose.POSE_CONNECTIONS)

        # 비디오 프레임 저장
        resize_frame = cv2.resize(frame, (1920, 1080))
        out.write(resize_frame)

        cv2.imshow('Fall Detection', resize_frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    out.release() 
    cv2.destroyAllWindows()
    
    return predictions

def extract_landmarks(results):
    landmarks = []
    for landmark in LANDMARKS:
        if results.pose_landmarks.landmark[landmark].visibility < 0.5:
            continue  # 가시성이 낮은 경우 무시
        
        x = results.pose_landmarks.landmark[landmark].x
        y = results.pose_landmarks.landmark[landmark].y
        landmarks.append([x, y])  # x와 y 좌표만 추가
    return landmarks

# 모델 로드 및 비디오 처리
model_path = 'only_mediapipe.pt'
video_path = 'D:\\human_fall\\re_video\\validation\\Y\\02308_H_A_SY_C3.mp4'
output_path = 'C:\\Users\\user\\Desktop\\prj_sample_vid\\GRU_pred_inputsize22_includeNormali2.mp4' 
input_size = 22

model = load_model(model_path, input_size)
predictions = process_video(video_path, model, output_path)

print("저장완료")
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 저장완료

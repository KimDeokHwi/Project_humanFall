# %% [markdown]
# ## MacOS에서 아이폰을 웹캠으로 활용한 실시간 감지 코드

# %%
import cv2
import torch
import numpy as np
import torch.nn as nn
import mediapipe as mp
import time
from ultralytics import YOLO

# %%
# MPS 사용 가능 여부 확인
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS")
else:
    device = torch.device("cpu")
    print("CPU")
# Out:
# MPS

# %%
# YOLOv8 모델 로드
yolo_model = YOLO('/Users/kimdeok-hwi/deeplearning/project/Project_humanFall/yolov8s.pt')

# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)

LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# 11개의 랜드마크만 선택 후 x, y 좌표만 추출
def process_landmarks(landmarks) : 
    selected_landmarks = landmarks[LANDMARKS]
    return selected_landmarks[ : , : 2].flatten()

# GRU 모델 로드
class GRUModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size = 64, num_layers = 2, output_size = 3, dropout = 0.5):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout = dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

input_size = 26 # 11개 랜드마크의 x, y 좌표 + 바운딩박스 비율
hidden_size = 64
num_layers = 2
output_size = 3
dropout = 0.5    

gru_model = GRUModel(input_size, hidden_size, num_layers, output_size, dropout)
gru_model.load_state_dict(torch.load('/Users/kimdeok-hwi/deeplearning/project/Project_humanFall/best_fall_detection_gru.pt', map_location=torch.device('cpu')))
gru_model.eval()

# iPhone 웹캠 초기화
cap = cv2.VideoCapture(0)  

# 비디오 저장 설정, MacOS에서는 'avc1' 코덱 사용
fourcc = cv2.VideoWriter_fourcc(*'avc1')
out = cv2.VideoWriter('output_with_iphone.mp4', fourcc, 24.0, (int(cap.get(3)), int(cap.get(4))))

# 낙상 감지 함수
def detect_fall(landmarks, bbox_width, bbox_height, bbox_ratio, confidence):
    processed_landmarks = process_landmarks(landmarks)
    # 바운딩 박스 너비와 높이를 포함하여 총 26개 특성
    input_data = np.concatenate([processed_landmarks, [bbox_width, bbox_height, bbox_ratio, confidence]])
    print('input_data shape:', input_data.shape)  # 디버깅 정보
    input_tensor = torch.FloatTensor(input_data).unsqueeze(0).unsqueeze(0)

    print(input_data.shape)
    
    with torch.no_grad():
        output = gru_model(input_tensor)
    
    predicted_class = torch.argmax(output, dim = 1).item()
    return predicted_class # 0 : 비낙상, 1 : 낙상 위험, 2 : 완전 낙상

# FPS 계산을 위한 변수
prev_time = 0
fps = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # FPS 계산
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time

    # YOLOv8로 사람 감지
    results = yolo_model(frame)
    
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy().astype(int)
        confidences = result.boxes.conf.cpu().numpy() # 신뢰도 점수 추출
        class_ids = result.boxes.cls.cpu().numpy() # 클래스 ID 추출
        
        for i, box in enumerate(boxes) :
            if class_ids[i] == 0 : 
                x1, y1, x2, y2 = box
                confidence = confidences[i] # 해당 박스의 신뢰도 점수
            
                # 바운딩 박스 비율 계산
                bbox_width = x2 - x1
                bbox_height = y2 - y1
                bbox_ratio = bbox_width / bbox_height
            
                # MediaPipe로 랜드마크 추출
                rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                results_pose = pose.process(rgb_frame)
            
                if results_pose.pose_landmarks:
                    landmarks = np.array([[lm.x, lm.y, lm.z] for lm in results_pose.pose_landmarks.landmark])
                
                    # 낙상 감지
                    is_fall = detect_fall(landmarks, bbox_width, bbox_height, bbox_ratio, confidence)
                
                    # 결과 표시
                    if is_fall == 0:
                        color = (0, 255, 0)  # 초록색 (비낙상)
                        label = "NORMAL"
                    elif is_fall == 1:
                        color = (0, 255, 255)  # 노란색 (낙상 위험)
                        label = "DANGER"
                    else:
                        color = (0, 0, 255)  # 빨간색 (완전 낙상)
                        label = "FALL"

                    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                    cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # FPS 표시
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # 프레임 저장
    out.write(frame)

    cv2.imshow('Fall Detection', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 2024-11-10 19:44:19.559 Python[2102:75258] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 1 keyboard, 65.2ms
# Speed: 1.6ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 laptop, 1 mouse, 1 keyboard, 72.6ms
# Speed: 1.7ms preprocess, 72.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 laptop, 67.4ms
# Speed: 1.5ms preprocess, 67.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 laptop, 1 cell phone, 84.8ms
# Speed: 1.5ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 cell phone, 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 72.7ms
# Speed: 2.2ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 66.8ms
# Speed: 1.4ms preprocess, 66.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 66.3ms
# Speed: 1.8ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 65.3ms
# Speed: 1.6ms preprocess, 65.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 62.3ms
# Speed: 1.5ms preprocess, 62.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 65.4ms
# Speed: 1.4ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.8ms
# Speed: 1.8ms preprocess, 61.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.4ms
# Speed: 1.9ms preprocess, 61.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 laptop, 65.8ms
# Speed: 1.7ms preprocess, 65.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 64.2ms
# Speed: 1.7ms preprocess, 64.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 61.0ms
# Speed: 1.8ms preprocess, 61.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.1ms
# Speed: 1.4ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 62.7ms
# Speed: 1.5ms preprocess, 62.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 64.6ms
# Speed: 1.7ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 63.7ms
# Speed: 1.7ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 72.8ms
# Speed: 1.8ms preprocess, 72.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 72.4ms
# Speed: 1.9ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 73.2ms
# Speed: 1.7ms preprocess, 73.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 72.4ms
# Speed: 1.5ms preprocess, 72.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 71.3ms
# Speed: 1.9ms preprocess, 71.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 62.4ms
# Speed: 1.7ms preprocess, 62.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 63.5ms
# Speed: 2.2ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.6ms
# Speed: 1.7ms preprocess, 59.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.0ms
# Speed: 1.6ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 80.2ms
# Speed: 1.6ms preprocess, 80.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 69.3ms
# Speed: 2.9ms preprocess, 69.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 75.3ms
# Speed: 1.7ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 64.7ms
# Speed: 1.7ms preprocess, 64.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.1ms
# Speed: 1.4ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.5ms
# Speed: 1.4ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 59.6ms
# Speed: 1.4ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 59.7ms
# Speed: 1.4ms preprocess, 59.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.2ms
# Speed: 1.4ms preprocess, 59.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.7ms
# Speed: 1.5ms preprocess, 59.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.5ms
# Speed: 1.4ms preprocess, 59.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.2ms
# Speed: 2.3ms preprocess, 59.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.3ms
# Speed: 1.4ms preprocess, 59.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.3ms
# Speed: 1.4ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.5ms
# Speed: 1.4ms preprocess, 59.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.8ms
# Speed: 2.2ms preprocess, 59.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.8ms
# Speed: 1.5ms preprocess, 60.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.7ms
# Speed: 2.5ms preprocess, 58.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 58.3ms
# Speed: 1.4ms preprocess, 58.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 56.4ms
# Speed: 1.5ms preprocess, 56.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 62.9ms
# Speed: 1.5ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.2ms
# Speed: 1.5ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 59.7ms
# Speed: 1.5ms preprocess, 59.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 60.0ms
# Speed: 1.4ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 cell phone, 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 laptops, 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 laptops, 59.6ms
# Speed: 1.4ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 laptops, 61.2ms
# Speed: 1.4ms preprocess, 61.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 laptops, 1 cell phone, 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 laptops, 66.0ms
# Speed: 1.5ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 person, 3 laptops, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 3 laptops, 59.3ms
# Speed: 1.6ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 1 cup, 3 laptops, 65.1ms
# Speed: 1.5ms preprocess, 65.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 2 laptops, 64.0ms
# Speed: 1.5ms preprocess, 64.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 1 cup, 2 laptops, 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 person, 1 cup, 5 laptops, 64.7ms
# Speed: 1.5ms preprocess, 64.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 3 laptops, 66.2ms
# Speed: 1.5ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 5 laptops, 1 sink, 71.4ms
# Speed: 1.7ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 4 laptops, 63.7ms
# Speed: 1.8ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 2 laptops, 70.5ms
# Speed: 1.6ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 chair, 2 laptops, 66.4ms
# Speed: 3.0ms preprocess, 66.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 5 laptops, 74.4ms
# Speed: 1.7ms preprocess, 74.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 2 laptops, 69.1ms
# Speed: 1.6ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 2 chairs, 4 laptops, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 1 cup, 2 laptops, 73.9ms
# Speed: 1.8ms preprocess, 73.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 dining table, 4 laptops, 69.3ms
# Speed: 1.8ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 5 laptops, 66.4ms
# Speed: 1.7ms preprocess, 66.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 2 cups, 1 chair, 5 laptops, 67.7ms
# Speed: 1.7ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 2 cups, 1 chair, 5 laptops, 74.0ms
# Speed: 1.8ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 2 cups, 1 chair, 5 laptops, 77.0ms
# Speed: 1.8ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 4 laptops, 69.3ms
# Speed: 1.7ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 1 cup, 1 chair, 5 laptops, 72.3ms
# Speed: 1.8ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 3 laptops, 70.0ms
# Speed: 1.7ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 3 laptops, 72.2ms
# Speed: 1.8ms preprocess, 72.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 tie, 1 cup, 4 laptops, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 cup, 1 chair, 3 laptops, 71.5ms
# Speed: 1.8ms preprocess, 71.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 1 cup, 4 laptops, 71.3ms
# Speed: 1.7ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 4 laptops, 61.9ms
# Speed: 1.5ms preprocess, 61.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 cup, 2 chairs, 5 laptops, 1 mouse, 1 cell phone, 69.7ms
# Speed: 2.8ms preprocess, 69.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 car, 1 cup, 2 chairs, 3 laptops, 76.0ms
# Speed: 2.8ms preprocess, 76.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 car, 1 cup, 2 chairs, 5 laptops, 73.9ms
# Speed: 1.7ms preprocess, 73.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 3 laptops, 76.8ms
# Speed: 1.7ms preprocess, 76.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 cup, 2 chairs, 5 laptops, 1 cell phone, 72.8ms
# Speed: 1.8ms preprocess, 72.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 5 laptops, 1 cell phone, 77.3ms
# Speed: 1.8ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 2 cups, 6 laptops, 77.4ms
# Speed: 1.8ms preprocess, 77.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 car, 1 cup, 1 dining table, 6 laptops, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 car, 1 cup, 7 laptops, 1 cell phone, 78.6ms
# Speed: 1.7ms preprocess, 78.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 5 laptops, 74.9ms
# Speed: 1.7ms preprocess, 74.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 7 laptops, 1 cell phone, 76.0ms
# Speed: 1.8ms preprocess, 76.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 6 laptops, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 car, 1 cup, 1 chair, 7 laptops, 1 cell phone, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 7 laptops, 1 cell phone, 81.6ms
# Speed: 1.8ms preprocess, 81.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 6 laptops, 1 cell phone, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 cup, 1 donut, 7 laptops, 74.6ms
# Speed: 1.8ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 cup, 6 laptops, 1 cell phone, 65.0ms
# Speed: 1.5ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 2 laptops, 65.4ms
# Speed: 1.5ms preprocess, 65.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 1 cup, 2 laptops, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 2 laptops, 61.1ms
# Speed: 1.4ms preprocess, 61.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 5 laptops, 60.3ms
# Speed: 1.4ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 persons, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 3 persons, 1 cup, 1 laptop, 59.6ms
# Speed: 1.5ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 4 persons, 2 laptops, 59.4ms
# Speed: 1.4ms preprocess, 59.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 1 chair, 2 laptops, 57.3ms
# Speed: 1.4ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 6 laptops, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 chair, 5 laptops, 64.4ms
# Speed: 1.5ms preprocess, 64.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 bottle, 2 cups, 2 chairs, 3 laptops, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 2 chairs, 4 laptops, 65.3ms
# Speed: 1.5ms preprocess, 65.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 9 persons, 1 bottle, 1 cup, 2 chairs, 4 laptops, 1 mouse, 65.5ms
# Speed: 2.8ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 8 persons, 1 bottle, 2 cups, 2 spoons, 1 bowl, 4 laptops, 66.8ms
# Speed: 1.6ms preprocess, 66.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 2 cups, 1 spoon, 2 chairs, 4 laptops, 64.6ms
# Speed: 1.6ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 11 persons, 1 bottle, 2 cups, 1 spoon, 1 chair, 4 laptops, 67.0ms
# Speed: 2.4ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 8 persons, 1 bottle, 2 cups, 1 spoon, 2 chairs, 4 laptops, 66.3ms
# Speed: 1.6ms preprocess, 66.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 2 cups, 1 fork, 2 chairs, 4 laptops, 61.1ms
# Speed: 1.5ms preprocess, 61.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 10 persons, 1 bottle, 3 cups, 1 fork, 1 chair, 3 dining tables, 4 laptops, 66.8ms
# Speed: 1.6ms preprocess, 66.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 2 cups, 2 forks, 5 laptops, 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 8 persons, 1 bottle, 2 cups, 2 forks, 1 chair, 4 laptops, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 bottle, 1 cup, 1 fork, 2 chairs, 4 laptops, 64.3ms
# Speed: 1.5ms preprocess, 64.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 2 cups, 1 spoon, 1 chair, 4 laptops, 65.8ms
# Speed: 1.5ms preprocess, 65.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 2 cups, 1 fork, 1 chair, 4 laptops, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 8 persons, 1 bottle, 2 cups, 1 fork, 2 chairs, 1 dining table, 4 laptops, 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 6 persons, 1 bottle, 2 cups, 1 dining table, 4 laptops, 1 keyboard, 80.5ms
# Speed: 1.7ms preprocess, 80.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 7 persons, 1 bottle, 3 cups, 1 fork, 1 dining table, 4 laptops, 1 keyboard, 78.3ms
# Speed: 1.8ms preprocess, 78.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 10 persons, 1 bottle, 3 cups, 2 chairs, 1 dining table, 6 laptops, 74.6ms
# ...
#
# 0: 384x640 (no detections), 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.7ms
# Speed: 1.8ms preprocess, 74.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.5ms
# Speed: 1.5ms preprocess, 72.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.8ms
# Speed: 2.3ms preprocess, 103.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.7ms
# Speed: 1.5ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 1.5ms preprocess, 62.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 1.5ms preprocess, 57.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 2 keyboards, 61.3ms
# Speed: 1.5ms preprocess, 61.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.9ms
# Speed: 1.4ms preprocess, 57.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.1ms
# Speed: 1.5ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.3ms
# Speed: 1.6ms preprocess, 62.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.1ms
# Speed: 1.5ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 2.1ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.1ms
# Speed: 1.5ms preprocess, 58.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.9ms
# Speed: 1.4ms preprocess, 57.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 1 laptop, 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 laptop, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 1.4ms preprocess, 57.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 laptop, 1 keyboard, 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.3ms
# Speed: 1.4ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.3ms
# Speed: 1.5ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.6ms
# Speed: 1.4ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.2ms
# Speed: 1.4ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.9ms
# Speed: 1.4ms preprocess, 61.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.9ms
# Speed: 1.5ms preprocess, 58.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 65.2ms
# Speed: 1.4ms preprocess, 65.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 72.0ms
# Speed: 1.6ms preprocess, 72.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 2 keyboards, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 keyboards, 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 63.0ms
# Speed: 1.4ms preprocess, 63.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.8ms
# Speed: 2.6ms preprocess, 60.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 60.2ms
# Speed: 1.5ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 1.5ms preprocess, 70.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 1.6ms preprocess, 72.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 62.1ms
# Speed: 2.3ms preprocess, 62.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 2 keyboards, 58.5ms
# Speed: 1.8ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.6ms
# Speed: 2.2ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.6ms
# Speed: 1.4ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.0ms
# Speed: 1.5ms preprocess, 80.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 63.5ms
# Speed: 1.5ms preprocess, 63.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 63.7ms
# Speed: 1.5ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 83.8ms
# Speed: 1.5ms preprocess, 83.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 68.1ms
# Speed: 1.6ms preprocess, 68.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 73.4ms
# Speed: 1.7ms preprocess, 73.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 68.4ms
# Speed: 1.4ms preprocess, 68.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 73.2ms
# Speed: 1.6ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 74.0ms
# Speed: 1.6ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 65.9ms
# Speed: 1.6ms preprocess, 65.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 3 keyboards, 60.5ms
# Speed: 1.6ms preprocess, 60.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 59.1ms
# Speed: 1.5ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.4ms
# Speed: 1.4ms preprocess, 61.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 57.2ms
# Speed: 1.4ms preprocess, 57.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 57.8ms
# Speed: 1.5ms preprocess, 57.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 58.5ms
# Speed: 1.5ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 61.4ms
# Speed: 1.4ms preprocess, 61.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 59.9ms
# Speed: 1.4ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 2 keyboards, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 2 keyboards, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 59.9ms
# Speed: 1.4ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.7ms
# Speed: 1.4ms preprocess, 58.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 keyboards, 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 61.2ms
# Speed: 1.4ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 57.8ms
# Speed: 1.4ms preprocess, 57.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.0ms
# Speed: 1.4ms preprocess, 59.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.6ms
# Speed: 2.1ms preprocess, 54.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.9ms
# Speed: 2.2ms preprocess, 59.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.9ms
# Speed: 1.4ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.1ms
# Speed: 1.4ms preprocess, 59.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 59.7ms
# Speed: 1.5ms preprocess, 59.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 58.4ms
# Speed: 1.4ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.3ms
# Speed: 1.4ms preprocess, 57.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 keyboard, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# -1

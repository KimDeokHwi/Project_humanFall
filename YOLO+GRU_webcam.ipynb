# %% [markdown]
# ## MacOS에서 아이폰을 웹캠으로 활용한 실시간 감지 코드

# %%
import cv2
import torch
import numpy as np
import torch.nn as nn
import mediapipe as mp
import time
from ultralytics import YOLO
# Out:
# objc[2290]: Class CaptureDelegate is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x30cf5e6b8) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x12fbdc860). One of the two will be used. Which one is undefined.
# objc[2290]: Class CVWindow is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x30cf5e708) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x12c5aca68). One of the two will be used. Which one is undefined.
# objc[2290]: Class CVView is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x30cf5e730) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x12c5aca90). One of the two will be used. Which one is undefined.
# objc[2290]: Class CVSlider is implemented in both /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cv2/cv2.abi3.so (0x30cf5e758) and /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x12c5acab8). One of the two will be used. Which one is undefined.

# %%
# MPS 사용 가능 여부 확인
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS")
else:
    device = torch.device("cpu")
    print("CPU")
# Out:
# MPS

# %%
# YOLOv8 모델 로드
yolo_model = YOLO('/Users/kimdeok-hwi/deeplearning/project/Project_humanFall/runs/detect/human_fall_s30/weights/best.pt')

# MediaPipe 초기화
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5)

LANDMARKS = [0, 11, 12, 15, 16, 23, 24, 25, 26, 27, 28]

# 11개의 랜드마크만 선택 후 x, y 좌표만 추출
def process_landmarks(landmarks) : 
    selected_landmarks = landmarks[LANDMARKS]
    return selected_landmarks[ : , : 2].flatten()

# GRU 모델 로드
class GRUModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size = 64, num_layers = 2, output_size = 3, dropout = 0.5):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout = dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

input_size = 26 # 11개 랜드마크의 x, y 좌표 + 바운딩박스 비율
hidden_size = 64
num_layers = 2
output_size = 3
dropout = 0.5    

gru_model = GRUModel(input_size, hidden_size, num_layers, output_size, dropout)
gru_model.load_state_dict(torch.load('/Users/kimdeok-hwi/deeplearning/project/Project_humanFall/GRU/add_sensordata_bbox.pt', map_location = device))
gru_model.eval()

# iPhone 웹캠 초기화
cap = cv2.VideoCapture(0)  

# 비디오 저장 설정, MacOS에서는 'avc1' 코덱 사용
fourcc = cv2.VideoWriter_fourcc(*'avc1')
out = cv2.VideoWriter('output_with_iphone.mp4', fourcc, 24.0, (int(cap.get(3)), int(cap.get(4))))

# 낙상 감지 함수
def detect_fall(landmarks, bbox_width, bbox_height, bbox_ratio, confidence):
    processed_landmarks = process_landmarks(landmarks)
    # 바운딩 박스 너비와 높이를 포함하여 총 26개 특성
    input_data = np.concatenate([processed_landmarks, [bbox_width, bbox_height, bbox_ratio, confidence]])
    print('input_data shape:', input_data.shape)  # 디버깅 정보
    input_tensor = torch.FloatTensor(input_data).unsqueeze(0).unsqueeze(0)

    print(input_data.shape)
    
    with torch.no_grad():
        output = gru_model(input_tensor)
    
    predicted_class = torch.argmax(output, dim = 1).item()
    return predicted_class # 0 : 비낙상, 1 : 낙상 위험, 2 : 완전 낙상

# FPS 계산을 위한 변수
prev_time = 0
fps = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # FPS 계산
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time

    # YOLOv8로 사람 감지
    results = yolo_model(frame)
    
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy().astype(int)
        confidences = result.boxes.conf.cpu().numpy() # 신뢰도 점수 추출
        class_ids = result.boxes.cls.cpu().numpy() # 클래스 ID 추출
        
        for i, box in enumerate(boxes) :
            if class_ids[i] == 0 : 
                x1, y1, x2, y2 = box
                confidence = confidences[i] # 해당 박스의 신뢰도 점수
            
                # 바운딩 박스 비율 계산
                bbox_width = x2 - x1
                bbox_height = y2 - y1
                bbox_ratio = bbox_width / bbox_height
            
                # MediaPipe로 랜드마크 추출
                rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                results_pose = pose.process(rgb_frame)
            
                if results_pose.pose_landmarks:
                    landmarks = np.array([[lm.x, lm.y, lm.z] for lm in results_pose.pose_landmarks.landmark])
                
                    # 낙상 감지
                    is_fall = detect_fall(landmarks, bbox_width, bbox_height, bbox_ratio, confidence)
                
                    # 결과 표시
                    if is_fall == 0:
                        color = (0, 255, 0)  # 초록색 (비낙상)
                        label = "NORMAL"
                    elif is_fall == 1:
                        color = (0, 255, 255)  # 노란색 (낙상 위험)
                        label = "DANGER"
                    else:
                        color = (0, 0, 255)  # 빨간색 (완전 낙상)
                        label = "FALL"

                    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                    cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # FPS 표시
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # 프레임 저장
    out.write(frame)

    cv2.imshow('Fall Detection', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 0: 384x640 (no detections), 85.0ms
# Speed: 1.9ms preprocess, 85.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 2.1ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 1.7ms preprocess, 82.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.7ms
# Speed: 2.4ms preprocess, 83.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 2.1ms preprocess, 82.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.2ms
# Speed: 2.5ms preprocess, 81.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.6ms
# Speed: 1.8ms preprocess, 79.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.0ms
# Speed: 1.8ms preprocess, 86.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.1ms
# Speed: 1.9ms preprocess, 82.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.6ms
# Speed: 1.6ms preprocess, 76.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.4ms
# Speed: 3.1ms preprocess, 79.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.4ms
# Speed: 1.6ms preprocess, 64.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 1.8ms preprocess, 66.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.5ms
# Speed: 1.6ms preprocess, 65.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.7ms
# Speed: 1.7ms preprocess, 74.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.6ms
# Speed: 1.7ms preprocess, 65.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.8ms
# Speed: 1.8ms preprocess, 81.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.0ms
# Speed: 1.7ms preprocess, 69.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 1.4ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.7ms
# Speed: 1.4ms preprocess, 76.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.1ms
# Speed: 1.9ms preprocess, 80.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.0ms
# Speed: 1.7ms preprocess, 72.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.5ms
# Speed: 1.9ms preprocess, 72.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.3ms
# Speed: 1.8ms preprocess, 78.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.3ms
# Speed: 1.7ms preprocess, 77.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.2ms
# Speed: 1.8ms preprocess, 67.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.8ms
# Speed: 2.3ms preprocess, 62.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.8ms
# Speed: 1.4ms preprocess, 59.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.3ms
# Speed: 1.4ms preprocess, 60.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.4ms
# Speed: 1.6ms preprocess, 66.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.8ms
# Speed: 1.8ms preprocess, 66.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.9ms
# Speed: 1.4ms preprocess, 62.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.9ms
# Speed: 1.4ms preprocess, 72.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.4ms
# Speed: 1.6ms preprocess, 65.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.3ms
# Speed: 1.5ms preprocess, 66.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.2ms
# Speed: 1.4ms preprocess, 67.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 1.5ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 1.4ms preprocess, 57.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.4ms
# Speed: 1.4ms preprocess, 56.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.8ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 59.5ms
# Speed: 1.4ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 1.4ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 56.0ms
# Speed: 1.4ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 72.9ms
# Speed: 1.4ms preprocess, 72.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 57.1ms
# Speed: 1.5ms preprocess, 57.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 53.8ms
# Speed: 2.1ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.4ms
# Speed: 1.6ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.5ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.7ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.8ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.7ms
# Speed: 1.5ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 2 Non_Falls, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 56.4ms
# Speed: 1.4ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.3ms
# Speed: 1.5ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.3ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 1.3ms preprocess, 52.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.3ms
# Speed: 1.8ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.7ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.4ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.7ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.8ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 51.9ms
# Speed: 1.3ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 57.1ms
# Speed: 1.5ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 68.9ms
# Speed: 1.6ms preprocess, 68.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.1ms
# Speed: 1.8ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.3ms
# Speed: 1.5ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.3ms
# Speed: 2.1ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.3ms
# Speed: 1.3ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 56.0ms
# Speed: 2.1ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.0ms
# Speed: 2.1ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 58.3ms
# Speed: 1.5ms preprocess, 58.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.3ms
# Speed: 1.8ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.8ms
# Speed: 1.6ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 54.8ms
# Speed: 1.9ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.7ms
# Speed: 1.4ms preprocess, 66.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.3ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.8ms
# Speed: 1.4ms preprocess, 56.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.9ms
# Speed: 1.7ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Fall, 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 1 Fall, 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 57.8ms
# Speed: 1.5ms preprocess, 57.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 57.7ms
# Speed: 1.5ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 58.7ms
# Speed: 1.8ms preprocess, 58.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 60.1ms
# Speed: 1.6ms preprocess, 60.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 1 Non_Fall, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.8ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 2.1ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fall, 54.8ms
# Speed: 2.2ms preprocess, 54.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 1.5ms preprocess, 58.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# ...
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 1.4ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.7ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.4ms preprocess, 52.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.3ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Non_Fall, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# input_data shape: (26,)
# (26,)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 2.1ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.8ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.3ms
# Speed: 1.9ms preprocess, 58.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 1.9ms preprocess, 60.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.8ms
# Speed: 1.4ms preprocess, 59.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.9ms
# Speed: 1.4ms preprocess, 61.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.7ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.3ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.7ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.4ms preprocess, 56.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.7ms
# Speed: 1.4ms preprocess, 56.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.4ms preprocess, 57.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.6ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.4ms preprocess, 57.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.3ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 1.4ms preprocess, 55.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 1.4ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.4ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# -1
